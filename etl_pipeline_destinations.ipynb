# %% [markdown]
# ### 1. Install Library

# %%
# %pip install pandas mysql-connector-python google-cloud-bigquery
# %pip install pandas-gbq

# %% [markdown]
# ### 2. Import Library

# %%
import pandas as pd
import mysql.connector
import os
from pandas_gbq import to_gbq
from google.oauth2 import service_account
from google.cloud import bigquery
from dotenv import load_dotenv

# %% [markdown]
# ### 3. Konfigurasi ke Database

# %%
# Load konfigurasi dari .env
load_dotenv()

# MySQL configurations
rds_host = os.getenv('RDS_HOST')
rds_dbname = os.getenv('RDS_DBNAME')
rds_user = os.getenv('RDS_USER')
rds_password = os.getenv('RDS_PASSWORD')

# Koneksi ke MySQL di Amazon RDS
conn_rds = mysql.connector.connect(
    host=rds_host,
    database=rds_dbname,
    user=rds_user,
    password=rds_password
)

# %% [markdown]
# ### 4. Extract

# %% [markdown]
# #### 4.1 Extract semua tabel dan jadikan dataframe

# %%
# List of tables to extract
tables = [
    'destinations', 'categories', 'destination_facilities', 'facilities',
    'destination_addresses', 'provinces', 'cities', 'subdistricts', 'destination_media'
]

# Function to load data from MySQL into pandas DataFrame
def load_table_to_df(table_name):
    query = f"SELECT * FROM {table_name}"
    df = pd.read_sql(query, conn_rds)
    return df

# %% [markdown]
# #### 4.2 Load semua tabel ke Dictionary

# %%
# Load all tables into individual DataFrames and store in a dictionary
dataframes = {}
for table in tables:
    df = load_table_to_df(table)
    dataframes[table] = df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_28856\3293516107.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn_rds)

# %% [markdown]
# #### 4.3 Close Connection

# %%
# Close the MySQL connection
conn_rds.close()

# %% [markdown]
# #### 4.4 Tampilkan Dataframe destinations

# %%
# Example of accessing and displaying a specific DataFrame
df_destinations = dataframes['destinations']
df_destinations
# Out:
#                                      id                           category_id  \
# 0  306d305e-3359-4884-8d38-89c04e8adea6  eb77b590-b255-4ea1-b11a-d445a259ac61
# 1  306d305e-3359-4884-8d38-89c04e8adec1  eb77b590-b255-4ea1-b11a-d445a259ac62
# 2  306d305e-3359-4884-8d38-89c04e8adec2  eb77b590-b255-4ea1-b11a-d445a259ac61
# 3  306d305e-3359-4884-8d38-89c04e8adec3  eb77b590-b255-4ea1-b11a-d445a259ac61
# 4  306d305e-3359-4884-8d38-89c04e8adec4  eb77b590-b255-4ea1-b11a-d445a259ac61
# 5  306d305e-3359-4884-8d38-89c04e8adec5  eb77b590-b255-4ea1-b11a-d445a259ac62
# 6  306d305e-3359-4884-8d38-89c04e8adec6  eb77b590-b255-4ea1-b11a-d445a259ac61
# 7  306d305e-3359-4884-8d38-89c04e8adec7  eb77b590-b255-4ea1-b11a-d445a259ac62
# 8  306d305e-3359-4884-8d38-89c04e8adec8  eb77b590-b255-4ea1-b11a-d445a259ac61
# 9  306d305e-3359-4884-8d38-89c04e8adec9  eb77b590-b255-4ea1-b11a-d445a259ac61
#
#                          name  \
# 0                  Kawah Ijen
# 1             Candi Borobudur
# 2                 Pantai Kuta
# 3                  Danau Toba
# 4  Taman Mini Indonesia Indah
# 5                Gunung Bromo
# 6                  Goa Pindul
# 7                Pulau Komodo
# 8                  Raja Ampat
# 9                   Tanah Lot
#
#                                          description open_time close_time  \
# 0  Kawah Ijen adalah sebuah kompleks gunung berap...     08:00      17:00
# 1  Candi Borobudur adalah sebuah candi Buddha yan...     08:00      17:00
# 2  Pantai Kuta adalah salah satu pantai yang terk...     08:00      17:00
# 3  Danau Toba adalah danau terbesar di Indonesia ...     08:00      17:00
# 4  Taman Mini Indonesia Indah adalah sebuah taman...     08:00      17:00
# 5  Gunung Bromo adalah sebuah gunung berapi aktif...     08:00      17:00
# 6  Gua tempat Joko terbentur tersebut dinamai Gua...     08:00      17:00
# 7  Pulau Komodo adalah sebuah pulau yang terletak...     08:00      17:00
# 8  Raja Ampat adalah kepulauan yang terletak di b...     08:00      17:00
# 9  Tanah Lot adalah sebuah formasi batuan di lepa...     08:00      17:00
#
#    entry_price  longitude  latitude  visit_count          created_at  \
# 0     100000.0   114.2423   -8.0582           23 2024-06-07 07:47:59
# 1      50000.0   110.2038   -7.6079            4 2024-06-07 07:47:59
# 2          0.0   115.1675   -8.7174            1 2024-06-07 07:47:59
# 3          0.0    99.0852    2.6696            0 2024-06-07 07:47:59
# 4      20000.0   106.8956   -6.3027            2 2024-06-07 07:47:59
# 5      30000.0   112.9528   -7.9425            1 2024-06-07 07:47:59
# 6      25000.0   123.4560  456.7890            1 2024-06-07 07:47:59
# 7     150000.0   119.4986   -8.5833            0 2024-06-07 07:47:59
# 8     500000.0   130.5036   -1.0562            1 2024-06-07 07:47:59
# 9      20000.0   115.0865   -8.6211            0 2024-06-07 07:47:59
#
#            updated_at deleted_at
# 0 2024-06-10 08:05:22       None
# 1 2024-06-10 08:05:24       None
# 2 2024-06-08 15:09:44       None
# 3 2024-06-07 07:47:59       None
# 4 2024-06-08 17:36:51       None
# 5 2024-06-10 08:05:30       None
# 6 2024-06-08 15:14:05       None
# 7 2024-06-07 07:47:59       None
# 8 2024-06-08 16:02:56       None
# 9 2024-06-07 07:47:59       None

# %% [markdown]
# #### 4.5 Tampilkan Dataframe categories

# %%
df_categories = dataframes['categories']
df_categories
# Out:
#                                      id             name  \
# 0  eb77b590-b255-4ea1-b11a-d445a259ac61             Alam
# 1  eb77b590-b255-4ea1-b11a-d445a259ac62  Seni dan Budaya
# 2  eb77b590-b255-4ea1-b11a-d445a259ac63          Sejarah
#
#                                                  url          created_at  \
# 0  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:53
# 1  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:53
# 2  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:53
#
#            updated_at deleted_at
# 0 2024-06-06 04:15:53       None
# 1 2024-06-10 09:41:51       None
# 2 2024-06-10 09:41:51       None

# %% [markdown]
# #### 4.6 Tampilkan Dataframe destination_facilities

# %%
df_destination_facilities = dataframes['destination_facilities']
df_destination_facilities
# Out:
#                                      id                        destination_id  \
# 0  eb77b590-b255-4ea1-b11a-d445a259ac80  306d305e-3359-4884-8d38-89c04e8adec9
# 1  eb77b590-b255-4ea1-b11a-d445a259ac81  306d305e-3359-4884-8d38-89c04e8adea6
#
#   province_id city_id subdistrict_id          street_name postal_code  \
# 0          95    9504         950433  Jalan Sam Ratulangi       95111
# 1          91    9106         910610     Jalan MH Thamrin       10110
# 2          35    3527         352705           Jalan Dago       40181
# 3          12    1212         121201      Jalan Tunjungan       60231
# 4          32    3213         321312      Jalan Malioboro       55281
# 5          35    3501         350105    Jalan Sunset Road       80228
# 6          74    7402         740225  Jalan Gatot Subroto       20151
# 7          35    3512         351209     Jalan Pandanaran       50149
# 8          35    3510         351024      Jalan Pettarani       90114
# 9          13    1310         131006       Jalan Sudirman       76125
#
#            created_at          updated_at deleted_at
# 0 2024-06-07 07:47:59 2024-06-07 07:47:59       None
# 1 2024-06-07 07:47:59 2024-06-07 07:47:59       None
# 2 2024-06-07 07:47:59 2024-06-07 07:47:59       None
# 3 2024-06-07 07:47:59 2024-06-07 07:47:59       None
# 4 2024-06-07 07:47:59 2024-06-07 07:47:59       None
# 5 2024-06-07 07:47:59 2024-06-07 07:47:59       None
# 6 2024-06-07 07:47:59 2024-06-07 07:47:59       None
# 7 2024-06-07 07:47:59 2024-06-07 07:47:59       None
# 8 2024-06-07 07:47:59 2024-06-07 07:47:59       None
# 9 2024-06-07 07:47:59 2024-06-07 07:47:59       None

# %% [markdown]
# #### 4.9 Tampilkan Dataframe provinces

# %%
df_provinces = dataframes['provinces']
df_provinces
# Out:
#     id                 name  \
# 0   11                 ACEH
# 1   12       SUMATERA UTARA
# 2   13       SUMATERA BARAT
# 3   14                 RIAU
# 4   15                JAMBI
# 5   16     SUMATERA SELATAN
# 6   17             BENGKULU
# 7   18              LAMPUNG
# 8   19      BANGKA BELITUNG
# 9   21       KEPULAUAN RIAU
# 10  31          DKI JAKARTA
# 11  32           JAWA BARAT
# 12  33          JAWA TENGAH
# 13  34        DI YOGYAKARTA
# 14  35           JAWA TIMUR
# 15  36               BANTEN
# 16  51                 BALI
# 17  52  NUSA TENGGARA BARAT
# 18  53  NUSA TENGGARA TIMUR
# 19  61     KALIMANTAN BARAT
# 20  62    KALIMANTAN TENGAH
# 21  63   KALIMANTAN SELATAN
# 22  64     KALIMANTAN TIMUR
# 23  65     KALIMANTAN UTARA
# 24  71       SULAWESI UTARA
# 25  72      SULAWESI TENGAH
# 26  73     SULAWESI SELATAN
# 27  74    SULAWESI TENGGARA
# 28  75            GORONTALO
# 29  76       SULAWESI BARAT
# 30  81               MALUKU
# 31  82         MALUKU UTARA
# 32  91                PAPUA
# 33  92          PAPUA BARAT
# 34  93        PAPUA SELATAN
# 35  94         PAPUA TENGAH
# 36  95     PAPUA PEGUNUNGAN
#
#                                                   url          created_at  \
# 0   https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:53
# 1   https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 2   https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 3   https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 4   https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 5   https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 6   https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 7   https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 8   https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 9   https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 10  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 11  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 12  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 13  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 14  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 15  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 16  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 17  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 18  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 19  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 20  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 21  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 22  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 23  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 24  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 25  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 26  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 27  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 28  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 29  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 30  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 31  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 32  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 33  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 34  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 35  https://res.cloudinary.com/alta-minpro/image/u... 2024-06-06 04:15:54
# 36  https://res.cloudinary.com/alta-minpro/image/u... 2024-06
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None

# %% [markdown]
# ### 5. Transformation

# %% [markdown]
# #### 5.1 Merged df_destination_facilities dan df_facilities

# %%
# Menggabungkan DataFrame
df_merged_facilities = pd.merge(df_destination_facilities, df_facilities, left_on='facility_id', right_on='id')

# Memilih kolom yang diinginkan dari df_facilities
df_dim_facilities = df_merged_facilities[['facility_id', 'name', 'url']].drop_duplicates()
df_dim_facilities.rename(columns={'facility_id': 'id'}, inplace=True)

# Mengurutkan index kembali
df_dim_facilities.reset_index(drop=True, inplace=True)

# %% [markdown]
# ##### 5.1.1 Dim Facilities

# %%
# Menampilkan DataFrame hasil
df_dim_facilities
# Out:
#                                      id                     name  \
# 0  515cb2da-3361-48b8-99fd-bd894828efa3          Pusat Kesehatan
# 1  515cb2da-3361-48b8-99fd-bd894828efd6           Toko Oleh-Oleh
# 2  515cb2da-3361-48b8-99fd-bd894828efa5  Tempat Penitipan Barang
# 3  515cb2da-3361-48b8-99fd-bd894828efd1              Kamar Mandi
# 4  515cb2da-3361-48b8-99fd-bd894828efa2              WiFi Gratis
# 5  515cb2da-3361-48b8-99fd-bd894828efd4               Penginapan
# 6  515cb2da-3361-48b8-99fd-bd894828efa4      Layanan Penjemputan
#
#                              url
# 0  https://picsum.photos/300/200
# 1  https://picsum.photos/300/200
# 2  https://picsum.photos/300/200
# 3  https://picsum.photos/300/200
# 4  https://picsum.photos/300/200
# 5  https://picsum.photos/300/200
# 6  https://picsum.photos/300/200

# %% [markdown]
# #### 5.2 Merged df_destination_addresses dengan df_provinces, df_cities, df_subdistricts

# %%
# Gabungkan DataFrame
df_merged_address = pd.merge(df_destination_addresses, df_provinces, left_on='province_id', right_on='id', suffixes=('_dest', '_prov'))
df_merged_address = pd.merge(df_merged_address, df_cities, left_on='city_id', right_on='id', suffixes=('_prov', '_city'))
df_merged_address = pd.merge(df_merged_address, df_subdistricts, left_on='subdistrict_id', right_on='id', suffixes=('_city', '_subd'))

# Pilih kolom yang diinginkan
df_dim_address = df_merged_address[['id_dest', 'name_prov', 'name_city', 'name', 'street_name', 'postal_code']]

# Ubah nama kolom
df_dim_address.columns = ['id', 'provinces', 'cities', 'subdistricts', 'street_name', 'postal_code']

# %% [markdown]
# ##### 5.2.1 Dim Address

# %%
# Tampilkan DataFrame hasil
df_dim_address
# Out:
#                                      id          provinces            cities  \
# 0  eb77b590-b255-4ea1-b11a-d445a259ac70   PAPUA PEGUNUNGAN     KAB. TOLIKARA
# 1  eb77b590-b255-4ea1-b11a-d445a259ac71              PAPUA  KAB. BIAK NUMFOR
# 2  eb77b590-b255-4ea1-b11a-d445a259ac72         JAWA TIMUR      KAB. SAMPANG
# 3  eb77b590-b255-4ea1-b11a-d445a259ac75         JAWA TIMUR      KAB. PACITAN
# 4  eb77b590-b255-4ea1-b11a-d445a259ac77         JAWA TIMUR    KAB. SITUBONDO
# 5  eb77b590-b255-4ea1-b11a-d445a259ac78         JAWA TIMUR   KAB. BANYUWANGI
# 6  eb77b590-b255-4ea1-b11a-d445a259ac73     SUMATERA UTARA         KAB. TOBA
# 7  eb77b590-b255-4ea1-b11a-d445a259ac74         JAWA BARAT       KAB. SUBANG
# 8  eb77b590-b255-4ea1-b11a-d445a259ac76  SULAWESI TENGGARA       KAB. KONAWE
# 9  eb77b590-b255-4ea1-b11a-d445a259ac79     SUMATERA BARAT  KAB. DHARMASRAYA
#
#   subdistricts          street_name postal_code
# 0       Wakuwo  Jalan Sam Ratulangi       95111
# 1      Padaido     Jalan MH Thamrin       10110
# 2        Omben           Jalan Dago       40181
# 3   Kebonagung    Jalan Sunset Road       80228
# 4     Mangaran     Jalan Pandanaran       50149
# 5        Licin      Jalan Pettarani       90114
# 6       Balige      Jalan Tunjungan       60231
# 7   Jalancagak      Jalan Malioboro       55281
# 8       Meluhu  Jalan Gatot Subroto       20151
# 9       Timpeh       Jalan Sudirman       76125

# %% [markdown]
# #### 5.3 Drop Column di df_destinations (Dim Destinations)

# %%
# Menghapus kolom-kolom yang tidak diinginkan
columns_to_drop = ['category_id', 'created_at', 'updated_at', 'deleted_at']
df_dim_destinations = df_destinations.drop(columns=columns_to_drop)

# Tampilkan hasil
df_dim_destinations
# Out:
#                                      id                        name  \
# 0  306d305e-3359-4884-8d38-89c04e8adea6                  Kawah Ijen
# 1  306d305e-3359-4884-8d38-89c04e8adec1             Candi Borobudur
# 2  306d305e-3359-4884-8d38-89c04e8adec2                 Pantai Kuta
# 3  306d305e-3359-4884-8d38-89c04e8adec3                  Danau Toba
# 4  306d305e-3359-4884-8d38-89c04e8adec4  Taman Mini Indonesia Indah
# 5  306d305e-3359-4884-8d38-89c04e8adec5                Gunung Bromo
# 6  306d305e-3359-4884-8d38-89c04e8adec6                  Goa Pindul
# 7  306d305e-3359-4884-8d38-89c04e8adec7                Pulau Komodo
# 8  306d305e-3359-4884-8d38-89c04e8adec8                  Raja Ampat
# 9  306d305e-3359-4884-8d38-89c04e8adec9                   Tanah Lot
#
#                                          description open_time close_time  \
# 0  Kawah Ijen adalah sebuah kompleks gunung berap...     08:00      17:00
# 1  Candi Borobudur adalah sebuah candi Buddha yan...     08:00      17:00
# 2  Pantai Kuta adalah salah satu pantai yang terk...     08:00      17:00
# 3  Danau Toba adalah danau terbesar di Indonesia ...     08:00      17:00
# 4  Taman Mini Indonesia Indah adalah sebuah taman...     08:00      17:00
# 5  Gunung Bromo adalah sebuah gunung berapi aktif...     08:00      17:00
# 6  Gua tempat Joko terbentur tersebut dinamai Gua...     08:00      17:00
# 7  Pulau Komodo adalah sebuah pulau yang terletak...     08:00      17:00
# 8  Raja Ampat adalah kepulauan yang terletak di b...     08:00      17:00
# 9  Tanah Lot adalah sebuah formasi batuan di lepa...     08:00      17:00
#
#    entry_price  longitude  latitude  visit_count
# 0     100000.0   114.2423   -8.0582           23
# 1      50000.0   110.2038   -7.6079            4
# 2          0.0   115.1675   -8.7174            1
# 3          0.0    99.0852    2.6696            0
# 4      20000.0   106.8956   -6.3027            2
# 5      30000.0   112.9528   -7.9425            1
# 6      25000.0   123.4560  456.7890            1
# 7     150000.0   119.4986   -8.5833            0
# 8     500000.0   130.5036   -1.0562            1
# 9      20000.0   115.0865   -8.6211            0

# %% [markdown]
# #### 5.4 Drop Column di df_categories (Dim Categories)

# %%
# Menghapus kolom-kolom yang tidak diinginkan
columns_to_drop = ['url', 'created_at', 'updated_at', 'deleted_at']
df_dim_categories = df_categories.drop(columns=columns_to_drop)

# Tampilkan DataFrame setelah penghapusan kolom
df_dim_categories
# Out:
#                                      id             name
# 0  eb77b590-b255-4ea1-b11a-d445a259ac61             Alam
# 1  eb77b590-b255-4ea1-b11a-d445a259ac62  Seni dan Budaya
# 2  eb77b590-b255-4ea1-b11a-d445a259ac63          Sejarah

# %% [markdown]
# #### 5.5 Drop Column di df_destination_media (Dim Medias)

# %%
# Menghapus kolom-kolom yang tidak diinginkan
columns_to_drop = ['destination_id', 'created_at', 'updated_at', 'deleted_at']
df_dim_medias = df_destination_media.drop(columns=columns_to_drop)

# Tampilkan DataFrame setelah penghapusan kolom
df_dim_medias
# Out:
#                                       id  \
# 0   1bde58e3-ef19-4daa-9df7-084ba5d3e930
# 1   1bde58e3-ef19-4daa-9df7-084ba5d3e931
# 2   1bde58e3-ef19-4daa-9df7-084ba5d3e932
# 3   1bde58e3-ef19-4daa-9df7-084ba5d3e933
# 4   1bde58e3-ef19-4daa-9df7-084ba5d3e934
# 5   1bde58e3-ef19-4daa-9df7-084ba5d3e935
# 6   1bde58e3-ef19-4daa-9df7-084ba5d3e936
# 7   1bde58e3-ef19-4daa-9df7-084ba5d3e937
# 8   1bde58e3-ef19-4daa-9df7-084ba5d3e938
# 9   1bde58e3-ef19-4daa-9df7-084ba5d3e939
# 10  1bde58e3-ef19-4daa-9df7-084ba5d3e940
# 11  1bde58e3-ef19-4daa-9df7-084ba5d3e941
# 12  1bde58e3-ef19-4daa-9df7-084ba5d3e942
# 13  1bde58e3-ef19-4daa-9df7-084ba5d3e943
# 14  1bde58e3-ef19-4daa-9df7-084ba5d3e944
# 15  1bde58e3-ef19-4daa-9df7-084ba5d3e945
# 16  1bde58e3-ef19-4daa-9df7-084ba5d3e946
# 17  1bde58e3-ef19-4daa-9df7-084ba5d3e947
# 18  1bde58e3-ef19-4daa-9df7-084ba5d3e948
# 19  1bde58e3-ef19-4daa-9df7-084ba5d3e949
#
#                                                   url   type  \
# 0   http://commondatastorage.googleapis.com/gtv-vi...  video
# 1   http://commondatastorage.googleapis.com/gtv-vi...  video
# 2   http://commondatastorage.googleapis.com/gtv-vi...  video
# 3   http://commondatastorage.googleapis.com/gtv-vi...  video
# 4   http://commondatastorage.googleapis.com/gtv-vi...  video
# 5   http://commondatastorage.googleapis.com/gtv-vi...  video
# 6   http://commondatastorage.googleapis.com/gtv-vi...  video
# 7   http://commondatastorage.googleapis.com/gtv-vi...  video
# 8   http://commondatastorage.googleapis.com/gtv-vi...  video
# 9   http://commondatastorage.googleapis.com/gtv-vi...  video
# 10                      https://picsum.photos/300/200  image
# 11                      https://picsum.photos/300/200  image
# 12                      https://picsum.photos/300/200  image
# 13                      https://picsum.photos/300/200  image
# 14                      https://picsum.photos/300/200  image
# 15                      https://picsum.photos/300/200  image
# 16                      https://picsum.photos/300/200  image
# 17                      https://picsum.photos/300/200  image
# 18                      https://picsum.photos/300/200  image
# 19                      https://picsum.photos/300/200  image
#
#                         title
# 0           Tears of Steel 10
# 1            Tears of Steel 1
# 2     Volkswagen GTI Review 2
# 3   We Are Going On Bullrun 3
# 4            Tears of Steel 4
# 5     Volkswagen GTI Review 5
# 6   We Are Going On Bullrun 6
# 7            Tears of Steel 7
# 8     Volkswagen GTI Review 8
# 9   We Are Going On Bullrun 9
# 10               Destinasi 10
# 11                Destinasi 1
# 12                Destinasi 2
# 13                Destinasi 3
# 14                Destinasi 4
# 15                Destinasi 5
# 16                Destinasi 6
# 17                Destinasi 7
# 18                Destinasi 8
# 19                Destinasi 9

# %% [markdown]
# #### 5.6 Merged for Fact Table (destination_fact)

# %%
# Merge dataframes
merged_df = pd.merge(df_destinations, df_categories, left_on='category_id', right_on='id', suffixes=('_destinations', '_categories'))
merged_df = pd.merge(merged_df, df_destination_media, left_on='id_destinations', right_on='destination_id')
merged_df = pd.merge(merged_df, df_destination_facilities, left_on='id_destinations', right_on='destination_id', how='left')
merged_df = pd.merge(merged_df, df_destination_addresses, left_on='id_destinations', right_on='destination_id', how='left')

merged_df
# Out:
#                          id_destinations  \
# 0   306d305e-3359-4884-8d38-89c04e8adea6
# 1   306d305e-3359-4884-8d38-89c04e8adea6
# 2   306d305e-3359-4884-8d38-89c04e8adec2
# 3   306d305e-3359-4884-8d38-89c04e8adec2
# 4   306d305e-3359-4884-8d38-89c04e8adec3
# 5   306d305e-3359-4884-8d38-89c04e8adec3
# 6   306d305e-3359-4884-8d38-89c04e8adec4
# 7   306d305e-3359-4884-8d38-89c04e8adec4
# 8   306d305e-3359-4884-8d38-89c04e8adec6
# 9   306d305e-3359-4884-8d38-89c04e8adec6
# 10  306d305e-3359-4884-8d38-89c04e8adec8
# 11  306d305e-3359-4884-8d38-89c04e8adec8
# 12  306d305e-3359-4884-8d38-89c04e8adec9
# 13  306d305e-3359-4884-8d38-89c04e8adec9
# 14  306d305e-3359-4884-8d38-89c04e8adec1
# 15  306d305e-3359-4884-8d38-89c04e8adec1
# 16  306d305e-3359-4884-8d38-89c04e8adec5
# 17  306d305e-3359-4884-8d38-89c04e8adec5
# 18  306d305e-3359-4884-8d38-89c04e8adec7
# 19  306d305e-3359-4884-8d38-89c04e8adec7
#
#                              category_id           name_destinations  \
# 0   eb77b590-b255-4ea1-b11a-d445a259ac61                  Kawah Ijen
# 1   eb77b590-b255-4ea1-b11a-d445a259ac61                  Kawah Ijen
# 2   eb77b590-b255-4ea1-b11a-d445a259ac61                 Pantai Kuta
# 3   eb77b590-b255-4ea1-b11a-d445a259ac61                 Pantai Kuta
# 4   eb77b590-b255-4ea1-b11a-d445a259ac61                  Danau Toba
# 5   eb77b590-b255-4ea1-b11a-d445a259ac61                  Danau Toba
# 6   eb77b590-b255-4ea1-b11a-d445a259ac61  Taman Mini Indonesia Indah
# 7   eb77b590-b255-4ea1-b11a-d445a259ac61  Taman Mini Indonesia Indah
# 8   eb77b590-b255-4ea1-b11a-d445a259ac61                  Goa Pindul
# 9   eb77b590-b255-4ea1-b11a-d445a259ac61                  Goa Pindul
# 10  eb77b590-b255-4ea1-b11a-d445a259ac61                  Raja Ampat
# 11  eb77b590-b255-4ea1-b11a-d445a259ac61                  Raja Ampat
# 12  eb77b590-b255-4ea1-b11a-d445a259ac61                   Tanah Lot
# 13  eb77b590-b255-4ea1-b11a-d445a259ac61                   Tanah Lot
# 14  eb77b590-b255-4ea1-b11a-d445a259ac62             Candi Borobudur
# 15  eb77b590-b255-4ea1-b11a-d445a259ac62             Candi Borobudur
# 16  eb77b590-b255-4ea1-b11a-d445a259ac62                Gunung Bromo
# 17  eb77b590-b255-4ea1-b11a-d445a259ac62                Gunung Bromo
# 18  eb77b590-b255-4ea1-b11a-d445a259ac62                Pulau Komodo
# 19  eb77b590-b255-4ea1-b11a-d445a259ac62                Pulau Komodo
#
#                                           description open_time close_time  \
# 0   Kawah Ijen adalah sebuah kompleks gunung berap...     08:00      17:00
# 1   Kawah Ijen adalah sebuah kompleks gunung berap...     08:00      17:00
# 2   Pantai Kuta adalah salah satu pantai yang terk...     08:00      17:00
# 3   Pantai Kuta adalah salah satu pantai yang terk...     08:00      17:00
# 4   Danau Toba adalah danau terbesar di Indonesia ...     08:00      17:00
# 5   Danau Toba adalah danau terbesar di Indonesia ...     08:00      17:00
# 6   Taman Mini Indonesia Indah adalah sebuah taman...     08:00      17:00
# 7   Taman Mini Indonesia Indah adalah sebuah taman...     08:00      17:00
# 8   Gua tempat Joko terbentur tersebut dinamai Gua...     08:00      17:00
# 9   Gua tempat Joko terbentur tersebut dinamai Gua...     08:00      17:00
# 10  Raja Ampat adalah kepulauan yang terletak di b...     08:00      17:00
# 11  Raja Ampat adalah kepulauan yang terletak di b...     08:00      17:00
# 12  Tanah Lot adalah sebuah formasi batuan di lepa...     08:00      17:00
# 13  Tanah Lot adalah sebuah formasi batuan di lepa...     08:00      17:00
# 14  Candi Borobudur adalah sebuah candi Buddha yan...     08:00      17:00
# 15  Candi Borobudur adalah sebuah candi Buddha yan...     08:00      17:00
# 16  Gunung Bromo adalah sebuah gunung berapi aktif...     08:00      17:00
# 17  Gunung Bromo adalah sebuah gunung berapi aktif...     08:00      17:00
# 18  Pulau Komodo adalah sebuah pulau yang terletak...     08:00      17:00
# 19  Pulau Komodo adalah sebuah pulau yang terletak...     08:00      17:00
#
#     entry_price  longitude  latitude  visit_count  ...  \
# 0      100000.0   114.2423   -8.0582           23  ...
# 1      100000.0   114.2423   -8.0582           23  ...
# 2           0.0   115.1675   -8.7174            1  ...
# 3           0.0   115.1675   -8.7174            1  ...
# 4           0.0    99.0852    2.6696            0  ...
# 5           0.0    99.0852    2.6696            0  ...
# 6       20000.0   106.8956   -6.3027            2  ...
# 7       20000.0   106.8956   -6.3027            2  ...
# 8       25000.0   123.4560  456.7890            1  ...
# 9       25000.0   123.4560  456.7890            1  ...
# 10     500000.0   130.5036   -1.0562            1  ...
# 11     500000.0   130.5036   -1.0562            1  ...
# 12      20000.0   115.0865   -8.6211            0  ...
# 13      20000.0   115.0865   -8.6211            0  ...
# 14      50000.0   110.2038   -7.6079            4  ...
# 15      50000.0   110.2038   -7.6079            4  ...
# 16      30000.0   112.9528   -7.9425            1  ...
# 17      30000.0   112.9528   -7.9425            1  ...
# 18     150000.0   119.4986   -8.5833            0  ...
# 19     150000.0   119.4986   -8.5833            0  ...
#
#                                       id  \
# 0   eb77b590-b255-4ea1-b11a-d445a259ac71
# 1   eb77b590-b255-4ea1-b11a-d445a259ac71
# 2   eb77b590-b255-4ea1-b11a-d445a259ac73
# 3   eb77b590-b255-4ea1-b11a-d445a259ac73
# 4   eb77b590-b255-4ea1-b11a-d445a259ac74
# 5   eb77b590-b255-4ea1-b11a-d445a259ac74
# 6   eb77b590-b255-4ea1-b11a-d445a259ac75
# 7   eb77b590-b255-4ea1-b11a-d445a259ac75
# 8   eb77b590-b255-4ea1-b11a-d445a259ac77
# 9   eb77b590-b255-4ea1-b11a-d445a259ac77
# 10  eb77b590-b255-4ea1-b11a-d445a259ac79
# 11  eb77b590-b255-4ea1-b11a-d445a259ac79
# 12  eb77b590-b255-4ea1-b11a-d445a259ac70
# 13  eb77b590-b255-4ea1-b11a-d445a259ac70
# 14  eb77b590-b255-4ea1-b11a-d445a259ac72
# 15  eb77b590-b255-4ea1-b11a-d445a259ac72
# 16  eb77b590-b255-4ea1-b11a-d445a259ac76
# 17  eb77b590-b255-4ea1-b11a-d445a259ac76
# 18  eb77b590-b255-4ea1-b11a-d445a259ac78
# 19  eb77b590-b255-4ea1-b11a-d445a259ac78
#
#                           destination_id province_id city_id subdistrict_id  \
# 0   306d305e-3359-4884-8d38-89c04e8adea6          91    9106         910610
# 1   306d305e-3359-4884-8d38-89c04e8adea6          91    9106         910610
# 2   306d305e-3359-4884-8d38-89c04e8adec2          12    1212         121201
# 3   306d305e-3359-4884-8d38-89c04e8adec2          12    1212         121201
# 4   306d305e-3359-4884-8d38-89c04e8adec3          32    3213         321312
# 5   306d305e-3359-4884-8d38-89c04e8adec3          32    3213         321312
# 6   306d305e-3359-4884-8d38-89c04e8adec4          35    3501         350105
# 7   306d305e-3359-4884-8d38-89c04e8adec4          35    3501         350105
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
#
# [20 rows x 43 columns]

# %%
print(merged_df.columns)
# Out:
# Index(['id_destinations', 'category_id', 'name_destinations', 'description',
#        'open_time', 'close_time', 'entry_price', 'longitude', 'latitude',
#        'visit_count', 'created_at_destinations', 'updated_at_destinations',
#        'deleted_at_destinations', 'id_categories', 'name_categories', 'url_x',
#        'created_at_categories', 'updated_at_categories',
#        'deleted_at_categories', 'id_x', 'destination_id_x', 'url_y', 'type',
#        'title', 'created_at_x', 'updated_at_x', 'deleted_at_x', 'id_y',
#        'destination_id_y', 'facility_id', 'created_at_y', 'updated_at_y',
#        'deleted_at_y', 'id', 'destination_id', 'province_id', 'city_id',
#        'subdistrict_id', 'street_name', 'postal_code', 'created_at',
#        'updated_at', 'deleted_at'],
#       dtype='object')

# %% [markdown]
# #### 5.7 Merged for Fact Table

# %%
# Calculate additional columns
merged_df['total_content_video'] = (merged_df['type'] == 'video').astype(int)
merged_df['total_pendapatan'] = merged_df['entry_price'] * merged_df['visit_count']

# Select relevant columns for fact table
df_destination_fact = merged_df[['id_destinations', 'category_id', 'id_x', 'facility_id', 'id', 'total_content_video', 'total_pendapatan']]

# Rename columns
df_destination_fact.columns = ['destinations_id', 'categories_id', 'medias_id', 'facilities_id', 'address_id', 'total_content_video', 'total_pendapatan']

# Drop duplicates
df_destination_fact = df_destination_fact.drop_duplicates()

# Preview the result
df_destination_fact
# Out:
#                          destinations_id  \
# 0   306d305e-3359-4884-8d38-89c04e8adea6
# 1   306d305e-3359-4884-8d38-89c04e8adea6
# 2   306d305e-3359-4884-8d38-89c04e8adec2
# 3   306d305e-3359-4884-8d38-89c04e8adec2
# 4   306d305e-3359-4884-8d38-89c04e8adec3
# 5   306d305e-3359-4884-8d38-89c04e8adec3
# 6   306d305e-3359-4884-8d38-89c04e8adec4
# 7   306d305e-3359-4884-8d38-89c04e8adec4
# 8   306d305e-3359-4884-8d38-89c04e8adec6
# 9   306d305e-3359-4884-8d38-89c04e8adec6
# 10  306d305e-3359-4884-8d38-89c04e8adec8
# 11  306d305e-3359-4884-8d38-89c04e8adec8
# 12  306d305e-3359-4884-8d38-89c04e8adec9
# 13  306d305e-3359-4884-8d38-89c04e8adec9
# 14  306d305e-3359-4884-8d38-89c04e8adec1
# 15  306d305e-3359-4884-8d38-89c04e8adec1
# 16  306d305e-3359-4884-8d38-89c04e8adec5
# 17  306d305e-3359-4884-8d38-89c04e8adec5
# 18  306d305e-3359-4884-8d38-89c04e8adec7
# 19  306d305e-3359-4884-8d38-89c04e8adec7
#
#                            categories_id  \
# 0   eb77b590-b255-4ea1-b11a-d445a259ac61
# 1   eb77b590-b255-4ea1-b11a-d445a259ac61
# 2   eb77b590-b255-4ea1-b11a-d445a259ac61
# 3   eb77b590-b255-4ea1-b11a-d445a259ac61
# 4   eb77b590-b255-4ea1-b11a-d445a259ac61
# 5   eb77b590-b255-4ea1-b11a-d445a259ac61
# 6   eb77b590-b255-4ea1-b11a-d445a259ac61
# 7   eb77b590-b255-4ea1-b11a-d445a259ac61
# 8   eb77b590-b255-4ea1-b11a-d445a259ac61
# 9   eb77b590-b255-4ea1-b11a-d445a259ac61
# 10  eb77b590-b255-4ea1-b11a-d445a259ac61
# 11  eb77b590-b255-4ea1-b11a-d445a259ac61
# 0   eb77b590-b255-4ea1-b11a-d445a259ac71                    1
# 1   eb77b590-b255-4ea1-b11a-d445a259ac71                    0
# 2   eb77b590-b255-4ea1-b11a-d445a259ac73                    1
# 3   eb77b590-b255-4ea1-b11a-d445a259ac73                    0
# 4   eb77b590-b255-4ea1-b11a-d445a259ac74                    1
# 5   eb77b590-b255-4ea1-b11a-d445a259ac74                    0
# 6   eb77b590-b255-4ea1-b11a-d445a259ac75                    1
# 7   eb77b590-b255-4ea1-b11a-d445a259ac75                    0
# 8   eb77b590-b255-4ea1-b11a-d445a259ac77                    1
# 9   eb77b590-b255-4ea1-b11a-d445a259ac77                    0
# 10  eb77b590-b255-4ea1-b11a-d445a259ac79                    1
# 11  eb77b590-b255-4ea1-b11a-d445a259ac79                    0
# 12  eb77b590-b255-4ea1-b11a-d445a259ac70                    1
# 13  eb77b590-b255-4ea1-b11a-d445a259ac70                    0
# 14  eb77b590-b255-4ea1-b11a-d445a259ac72                    1
# 15  eb77b590-b255-4ea1-b11a-d445a259ac72                    0
# 16  eb77b590-b255-4ea1-b11a-d445a259ac76                    1
# 17  eb77b590-b255-4ea1-b11a-d445a259ac76                    0
# 18  eb77b590-b255-4ea1-b11a-d445a259ac78                    1
# 19  eb77b590-b255-4ea1-b11a-d445a259ac78                    0
#
#     total_pendapatan
# 0          2300000.0
# 1          2300000.0
# 2                0.0
# 3                0.0
# 4                0.0
# 5                0.0
# 6            40000.0
# 7            40000.0
# 8            25000.0
# 9            25000.0
# 10          500000.0
# 11          500000.0
# 12               0.0
# 13               0.0
# 14          200000.0
# 15          200000.0
# 16           30000.0
# 17           30000.0
# 18               0.0
# 19               0.0

# %% [markdown]
# ### 6. Load to Big Query

# %% [markdown]
# #### 6.1 Konfigurasi ke Big Query

# %%
# Load environment variables from .env file
load_dotenv()

# Google Cloud configurations
project_id = os.getenv('GOOGLE_CLOUD_PROJECT_ID')
dataset_id = os.getenv('GOOGLE_CLOUD_DATASET_ID')
google_application_credentials = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')

# Set GOOGLE_APPLICATION_CREDENTIALS environment variable
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = google_application_credentials

# Load Google Cloud credentials
credentials = service_account.Credentials.from_service_account_file(google_application_credentials)

# %% [markdown]
# #### 6.2 Load dataframe to big query

# %%
# Dictionary to map DataFrame names to BigQuery table names
dataframes = {
    'dim_facilities': df_dim_facilities,
    'dim_address': df_dim_address,
    'dim_destinations': df_dim_destinations,
    'dim_categories': df_dim_categories,
    'dim_medias': df_dim_medias,
    'destination_fact': df_destination_fact,
}

# Function to load DataFrame into BigQuery
def load_to_bq(df, table_name):
    table_id = f"{project_id}.{dataset_id}.{table_name}"
    to_gbq(df, table_id, project_id=project_id, if_exists='replace', credentials=credentials)

# Iterate over DataFrame dictionary and load each to BigQuery
for table_name, df in dataframes.items():
    load_to_bq(df, table_name)

print("All dataframes loaded to BigQuery successfully.")
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 8577.31it/s]
# All dataframes loaded to BigQuery successfully.
