# %% [markdown]
# ### 1. Install Library

# %%
# %pip install pandas-gbq google-cloud-bigquery
# %pip install pandas-gbq google-auth google-auth-oauthlib

# %% [markdown]
# ### 2. Import Library

# %%
import pandas as pd
import mysql.connector
from google.oauth2 import service_account
from google.cloud import bigquery
import pandas_gbq
from pandas_gbq import to_gbq
import os
from dotenv import load_dotenv
from datetime import datetime, timedelta

# %% [markdown]
# ### 3. Database Configuration

# %%
# Load konfigurasi dari .env
load_dotenv()

# MySQL configurations
rds_host = os.getenv('RDS_HOST')
rds_dbname = os.getenv('RDS_DBNAME')
rds_user = os.getenv('RDS_USER')
rds_password = os.getenv('RDS_PASSWORD')

# Google Cloud configurations
project_id = os.getenv('GOOGLE_CLOUD_PROJECT_ID')
dataset_id = os.getenv('GOOGLE_CLOUD_DATASET_ID')
google_application_credentials = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = google_application_credentials

# Koneksi ke MySQL di Amazon RDS
conn_rds = mysql.connector.connect(
    host=rds_host,
    database=rds_dbname,
    user=rds_user,
    password=rds_password
)

# %% [markdown]
# ### 4. Extract

# %% [markdown]
# #### table_to_df function below is used to extract data from a table and convert it into a dataframe

# %%
def table_to_df(table_name):
   query = f"SELECT * FROM {table_name}"
   df = pd.read_sql_query(query, conn_rds)
   return df

# %% [markdown]
# #### 4.1 Converting data from tables to dataframes

# %%
destinations_df = table_to_df('destinations')
routes_df = table_to_df('routes')
route_details_df = table_to_df('route_details')
users_df = table_to_df('users')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_24800\1223067120.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn_rds)

# %% [markdown]
# #### 4.2 destinations dataframe

# %%
destinations_df
# Out:
#                                        id  \
# 0    00319825-e81b-4a93-bf9a-eef836ccf6ce
# 1    005e32da-f5fb-405c-9772-f6424c011fac
# 2    01b8da3a-3987-4976-9ae7-46d6b8eacee5
# 3    01ccaac9-97fe-42e1-8034-bc0c02471692
# 4    02834099-7ce7-44b9-8b27-e4db38f062bd
# ..                                    ...
# 428  fbee819e-2b7b-44fe-8d5a-74dd345cea0e
# 429  fc780065-0848-467b-9625-9c24ecd2e9c2
# 430  fde8748a-2ec0-4211-89e5-12f3d63db81b
# 431  fe1ebfe5-365f-4893-aa36-91e380bb2011
# 432  ff779270-ee68-46cc-929c-cdd67d328772
#
#                               category_id                         name  \
# 0    eb77b590-b255-4ea1-b11a-d445a259ac62  Keraton Kasunanan Surakarta
# 1    eb77b590-b255-4ea1-b11a-d445a259ac62         Desa Wisata Kasongan
# 2    eb77b590-b255-4ea1-b11a-d445a259ac62          Saung Angklung Udjo
# 3    eb77b590-b255-4ea1-b11a-d445a259ac62    Museum Etnografi Sendawar
# 4    eb77b590-b255-4ea1-b11a-d445a259ac61                Danau Limboto
# ..                                    ...                          ...
# 428  eb77b590-b255-4ea1-b11a-d445a259ac61                  Danau Tahai
# 429  eb77b590-b255-4ea1-b11a-d445a259ac61                  Pantai Maaf
# 430  eb77b590-b255-4ea1-b11a-d445a259ac61          Piaynemo Raja Ampat
# 431  eb77b590-b255-4ea1-b11a-d445a259ac61           Wisata Pantai Gedo
# 432  eb77b590-b255-4ea1-b11a-d445a259ac61                 Danau Emfote
#
#                                            description open_time close_time  \
# 0    Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 1    Desa yang terkenal dengan kerajinan gerabah da...      8:00      17:00
# 2    Saung Angklung Udjo adalah pusat Seni dan Buda...      8:00      17:00
# 3    Museum Etnografi Sendawar merupakan museum per...      9:00      18:00
# 4    Danau ini terletak di Kecamatan Limboto, tepat...      0:00      23:59
# ..                                                 ...       ...        ...
# 428  Di kawasan objek wisata Danau Tahai ini terdap...      0:00      23:59
# 429  Pantai Maaf menawarkan perairan yang damai den...      6:00      18:00
# 430  Piaynemo adalah salah satu ikon wisata di Raja...     10:00      17:00
# 431  Wisata Pantai Gedo adalah destinasi pantai ind...      6:00      18:00
# 432  Danau Emfote adalah salah satu destinasi alam ...      0:00      23:59
#
#      entry_price   longitude  latitude  visit_count          created_at  \
# 0        20000.0  110.827903 -7.577736          293 2024-06-11 08:28:33
# 1            0.0  110.337978 -7.845291          243 2024-06-11 08:28:27
# 2       120000.0  107.654684 -6.897701          203 2024-06-11 08:28:33
# 3         5000.0  115.701909 -0.232651          134 2024-06-11 08:28:20
# 4            0.0  123.007543  0.577025          219 2024-06-11 08:28:21
# ..           ...         ...       ...          ...                 ...
# 428          0.0  113.783202 -2.027312          136 2024-06-11 08:28:19
# 429      10000.0  135.496749 -3.360245          163 2024-06-11 08:28:32
# 430     150000.0  130.270813 -0.564206          123 2024-06-11 08:28:32
# 431      15000.0  135.546550 -3.309413          300 2024-06-11 08:28:32
# 432      20000.0  140.539693 -2.660878          208 2024-06-11 08:28:30
#
#              updated_at              deleted_at
# 0   2024-06-20 09:53:01 2024-06-20 09:53:01.786
# 1   2024-06-20 09:55:01 2024-06-20 09:55:01.453
# 2   2024-06-20 09:55:14 2024-06-20 09:55:14.647
# 3   2024-06-20 10:00:54 2024-06-20 10:00:54.207
# 4   2024-06-20 10:02:09 2024-06-20 10:02:09.429
# ..                  ...                     ...
# 428 2024-06-11 08:28:19                     NaT
# 429 2024-06-11 08:28:32                     NaT
# 430 2024-06-11 08:28:32                     NaT
# 431 2024-06-23 06:37:28                     NaT
# 432 2024-06-23 11:05:19                     NaT
#
# [433 rows x 13 columns]

# %% [markdown]
# #### 4.3 routes dataframe

# %%
routes_df
# Out:
#                                        id  \
# 0    0170287c-00ad-4c97-a873-7ef6e13be7fb
# 1    02dcc9f2-1970-4a36-9031-b434a618e1a7
# 2    02f6854d-1b57-4079-a2e3-394e9f037bb4
# 3    0458f0ec-4bbe-4950-99ad-afd5f48762d3
# 4    08aa6f3c-acb9-424d-8a74-7ab2605c9965
# ..                                    ...
# 118  f7eb9190-deb0-4d46-9e3e-6e68a886857c
# 119  fca75cfb-7cee-46bf-b505-68ecd0a52a11
# 120  fcd77473-4635-478f-9aff-62a1e98ef274
# 121  ff93ad6e-0e2a-484b-87eb-ad57fb75a6d7
# 122  ffe5b436-6552-44b5-931b-3fedf7185b9a
#
#                                   user_id city_id                name  \
# 0    16c77b92-1cb6-476e-8b58-dbffbb0ec8b9    1306                ruut
# 1    16c77b92-1cb6-476e-8b58-dbffbb0ec8b9    3204              asdasd
# 2    ac91e0a6-0c10-4d88-b253-294b6eb661cf    3204  Liburan ke Bandung
# 3    a48e02bb-6a68-4586-85e4-b038d795da5b    3204       bandung day 1
# 4    16c77b92-1cb6-476e-8b58-dbffbb0ec8b9    1104                 asd
# ..                                    ...     ...                 ...
# 118  16c77b92-1cb6-476e-8b58-dbffbb0ec8b9    9304               ruyut
# 119  16c77b92-1cb6-476e-8b58-dbffbb0ec8b9    7503              ruutte
# 120  16c77b92-1cb6-476e-8b58-dbffbb0ec8b9    7503              ruutte
# 121  16c77b92-1cb6-476e-8b58-dbffbb0ec8b9    9304                ruut
# 122  16c77b92-1cb6-476e-8b58-dbffbb0ec8b9    5103                ruut
#
#                                         start_location  start_longitude  \
# 0    Jl. Polowijen 1 No.4, Polowijen Kecamatan Blim...       112.648475
# 1    Jl. Polowijen 1 No.4, Polowijen Kecamatan Blim...       112.648475
# 2                                          Gedung Sate       107.620761
# 3    1600 Amphitheatre Pkwy Building 43,  Mountain ...      -122.084000
# 4    Jl. Polowijen 1 No.4, Polowijen Kecamatan Blim...       112.648475
# ..                                                 ...              ...
# 118  2JMM+932, Samaan Klojen Malang City, East Java...        21.000000
# 119  2JMM+932, Samaan Klojen Malang City, East Java...        21.000000
# 120  2JMM+932, Samaan Klojen Malang City, East Java...        21.000000
# 121  2JMM+932, Samaan Klojen Malang City, East Java...        21.000000
# 122  Jl. Polowijen 1 No.4, Polowijen Kecamatan Blim...       112.648475
#
#      start_latitude      price          created_at          updated_at  \
# 0         -7.928018  3500000.0 2024-06-21 15:44:00 2024-06-23 23:53:48
# 1         -7.928018    30000.0 2024-06-21 16:25:42 2024-06-24 01:16:26
# 2         -6.916096   200000.0 2024-06-19 07:35:14 2024-06-21 08:56:09
# 3         37.421998   200000.0 2024-06-23 09:15:22 2024-06-23 09:15:22
# 4         -7.928018   500000.0 2024-06-21 16:28:23 2024-06-23 08:53:19
# ..              ...        ...                 ...                 ...
# 118       -7.966620    50000.0 2024-06-21 13:21:52 2024-06-21 13:21:52
# 119       -7.966620    50000.0 2024-06-21 12:22:30 2024-06-21 12:22:30
# 120       -7.966620    50000.0 2024-06-21 12:21:34 2024-06-21 12:21:34
# 121       -7.966620    50000.0 2024-06-21 12:26:46 2024-06-21 12:26:46
# 122       -7.928018    85000.0 2024-06-21 15:07:17 2024-06-21 15:07:17
#
#                  deleted_at
# 0   2024-06-23 23:53:48.933
# 1   2024-06-24 01:16:26.815
# 2   2024-06-21 08:56:09.855
# 3                       NaT
# 4   2024-06-23 08:53:19.107
# ..                      ...
# 118                     NaT
# 119                     NaT
# 120                     NaT
# 121                     NaT
# 122                     NaT
#
# [123 rows x 11 columns]

# %% [markdown]
# #### 4.4 route_details dataframe

# %%
route_details_df
# Out:
#                                        id  \
# 0    01ba3f24-769f-4d01-a8a2-4bb88355fba5
# 1    01d3401f-0e80-4181-b31f-2399ba20d5ff
# 2    0376514c-37af-49da-b9b5-1f934bcc0827
# 3    03dab2c8-7290-41e2-a07e-916824d12ca8
# 4    04b5cb11-69e2-4175-9fb4-3fc45e71c3b8
# ..                                    ...
# 182  f4449f3e-995d-458b-9ed1-a94e338cc1ac
# 183  f5009d18-3e42-4832-9f62-be7d5fdb25e8
# 184  f6054c5d-d8a7-4800-96f3-e5c07fcf5af2
# 185  fc33e4ac-09ee-4192-bf1b-1fffc89fa09c
# 186  ffa44445-cf56-44ae-a25b-c6ebbc60fabf
#
#                            destination_id  \
# 0    10d45453-c83f-4d23-bcbe-5373ddcb8807
# 1    9ccd422e-50ab-4c4d-b713-598ca0311b77
# 2    5299d103-851a-4cef-b66f-dfc85a9a6ed0
# 3    45c50f14-480f-446e-bf5c-e27b4aabfe0c
# 4    aab8d2dc-d968-4233-92c4-6dc19ae143c6
# ..                                    ...
# 182  4ce34993-985e-4e27-a31e-4753e6b8ef23
# 183  b3bbb0ed-c092-4cc8-af76-59f883e51738
# 184  eb8122b0-9f90-46f1-9bd2-5366fe0a40c7
# 185  6a724317-15aa-4890-ab1f-7758106ad6d2
# 186  2f08e77f-81ea-4374-b137-b78fa5fb1da1
#
#                                  route_id   longitude  latitude  duration  \
# 0    a2ffb695-4828-4685-865d-4f63a194a272  107.576041 -6.798706     64800
# 1    72d5d30f-2f44-4ade-b384-1cfc1f209b45  100.217877 -0.353873     97920
# 2    940eff30-b415-491f-8408-8bdaf95e0adb  107.207205 -7.018241     10800
# 3    b3227e41-daff-48e9-a232-e9dc3fc2e328   96.996653  4.592379     21600
# 4    14f17375-f45f-46cd-9025-b813a9ef6075  106.889957 -6.301783     18000
# ..                                    ...         ...       ...       ...
# 182  2eef2911-7f83-4a0a-90fa-8dbdb36987b2  103.159275 -4.022511      2700
# 183  30dca53e-f902-49ca-812a-38a586b386d3  116.461640 -8.410276      5400
# 184  cc53f754-4d5c-4bdd-b9d9-9cf44ba8b187  114.573132 -3.293217      1200
# 185  cd5bd9b5-1072-40ee-9b57-afb22d8b894e  100.192011 -0.305623     25200
# 186  cf0c6d65-9ab3-44b9-bd1a-cf44304f5827  107.654684 -6.897701      5400
#
#      order     visit_start       visit_end          created_at  \
# 0        1 0 days 09:00:00 0 days 10:30:00 2024-06-21 16:31:30
# 1        1 0 days 11:30:00 0 days 13:00:00 2024-06-21 16:14:46
# 2        2 0 days 11:30:00 0 days 12:30:00 2024-06-21 16:30:39
# 3        1 0 days 11:30:00 0 days 15:00:00 2024-06-21 16:17:07
# 4        1 0 days 16:30:00 0 days 18:00:00 2024-06-21 16:03:41
# ..     ...             ...             ...                 ...
# 182      2 0 days 11:00:00 0 days 11:45:00 2024-06-23 06:50:01
# 183      1 0 days 07:00:00 0 days 14:00:00 2024-06-23 13:17:14
# 184      2 0 days 14:00:00 0 days 15:30:00 2024-06-23 08:08:46
# 185      1 0 days 10:00:00 0 days 11:00:00 2024-06-21 13:28:50
# 186      3 0 days 15:00:00 0 days 16:30:00 2024-06-23 09:11:17
#
#              updated_at deleted_at
# 0   2024-06-21 16:31:30        NaT
# 1   2024-06-21 16:14:46        NaT
# 2   2024-06-21 16:30:39        NaT
# 3   2024-06-21 16:17:07        NaT
# 4   2024-06-21 16:03:41        NaT
# ..                  ...        ...
# 182 2024-06-23 06:50:01        NaT
# 183 2024-06-23 13:17:14        NaT
# 184 2024-06-23 08:08:46        NaT
# 185 2024-06-21 13:28:50        NaT
# 186 2024-06-23 09:11:17        NaT
#
# [187 rows x 12 columns]

# %% [markdown]
# #### 4.5 users dataframe

# %%
users_df
# Out:
#                                        id                        email  \
# 0    00862788-5ded-4065-8275-2569748f64aa       xifihi49190@huleos.com
# 1    00bddbb8-8e7d-46ab-acfc-aab981c1ada1  irsyadyazidsyafiq@gmail.com
# 2    03d7240b-3e9b-4105-ac93-a926b752bb81             shuu@example.com
# 3    0483c5ae-046a-403a-a656-db920635396b      johndoe2345@example.com
# 4    05d6e970-851b-4a8d-8869-587ebe5273cd           ulfiizza@gmail.com
# ..                                    ...                          ...
# 175  fa95b90d-41a8-44fe-aea8-e3b1553532c8      puterisalsaa8@gmail.com
# 176  fc21e23a-ca8c-4cf9-8c5d-f1a56b431022             xhyeni@gmail.com
# 177  fc9e86d9-e3ba-42eb-a46c-16ba07dfeb74        tajoli5069@javnoi.com
# 178  fd13566c-bd12-4088-8537-2a52dbdca23b        Nausicaa5@example.com
# 179  fd84765b-865a-4c9b-9cc5-93ca3836e6de     zerenitymods01@gmail.com
#
#                                               password      username  \
# 0    $2a$10$ToBK0ZSXzQHhU9KEod/gk.jk.Fr5VlxUkdz.dLl...  testverify10
# 1    $2a$10$kcd7TdvXiS9QNHvFcLlsEe.pqUerZd3cEM7IKZc...  yazid.syafiq
# 2    $2a$10$IMijbn2w2PxgbgBW5399f.mXxUhLcHL9Nuv29lT...        paimon
# 3    $2a$10$Dxg27rgrHy1bZPiD0jNI8uInxr/duxnf3QEH8IS...   johndoe2443
# 4    $2a$10$2eFAkCeXNgTy69xF8gaIC.cdEOaiCB7q.olRjeK...          ulfi
# ..                                                 ...           ...
# 175  $2a$10$fkklkqERHa.hDRZxlPHhp.dzWPhwSchFLKzC4y0...      inisalsa
# 176  $2a$10$QpNu5wnAwZQKjvZc3QijZ.mjhw7XSx5FSC.UmjE...        xhyeni
# 177  $2a$10$D5rUZTz5z2SkdRJMeogJLODp2Xp9kHSLTVtNTrC...  testverfiy25
# 178  $2a$10$mR0l7hjnGtU6PF9V1LHTFerCZXqK.w7vBy.M.h0...     Nausicaa5
# 179  $2a$10$/lQPZ5g99QUv/TiK20NenOQFCBKEFaiVFMqX5eN...        rayhan
#
#             fullname bio   phone_number  \
# 0           John Doe       081234567891
# 1      Yazid Syafiq        081393984849
# 2       nama_lengkap       081234567890
# 3           John Doe       081234567891
# 4          ulfi izza       089123456789
# ..               ...  ..            ...
# 175  Salsa Maulidina        08115122238
# 176    xhyeni ananda       086182836712
# 177      Test Verify        08123456789
# 178         John Doe       081234567891
# 179         rayhanqr      0895320511122
#
#                                      profile_image_url  gender       city  \
# 0
# 1    https://res.cloudinary.com/alta-minpro/image/u...    Pria  Pringsewu
# 2                                              img.jpg  Wanita     Jaksel
# 3
# 4    https://res.cloudinary.com/alta-minpro/image/u...  Wanita     malang
# ..                                                 ...     ...        ...
# 175                                               None
# 176  https://res.cloudinary.com/alta-minpro/image/u...  Wanita     Malang
# 177
# 178                                               None
# 179                                               None
#
#           email_verified_at              created_at              updated_at  \
# 0   2024-06-22 09:00:44.000 2024-02-28 19:19:30.231 2024-05-27 15:26:01.704
# 1   2024-05-31 11:59:19.353 2024-05-18 03:32:14.211 2024-06-24 01:31:26.004
# 2                       NaT 2024-06-16 06:33:53.904 2024-06-23 11:22:47.505
# 3                       NaT 2024-03-15 21:04:00.423 2024-05-25 15:12:44.106
# 4                       NaT 2024-02-16 14:12:42.942 2024-06-16 14:37:19.404
# ..                      ...                     ...                     ...
# 175 2024-06-10 12:12:21.233 2024-02-06 22:12:37.382 2024-06-10 12:12:23.104
# 176                     NaT 2024-01-28 06:02:07.294 2024-06-19 06:14:44.495
# 177 2024-05-28 07:16:51.573 2024-01-26 19:32:43.861 2024-05-28 07:16:51.576
# 178                     NaT 2024-02-17 15:37:16.964 2024-06-12 07:00:16.507
# 179 2024-06-16 09:23:46.538 2024-06-10 03:28:12.777 2024-06-16 09:23:49.107
#
#                  deleted_at    province  \
# 0   2024-06-23 08:48:48.470
# 1                       NaT     Lampung
# 2                       NaT     Jakarta
# 3   2024-06-05 14:46:44.405        None
# 4                       NaT  jawa timur
# ..                      ...         ...
# 175                     NaT
# 176                     NaT  Jawa Timur
# 177                     NaT
# 178                     NaT
# 179                     NaT
#
#                                          refresh_token
# 0                                                 None
# 1    eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJZCI6I...
# 2
# 3                                                 None
# 4
# ..                                                 ...
# 175  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJZCI6I...
# 176
# 177                                               None
# 178
# 179  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJZCI6I...
#
# [180 rows x 16 columns]

# %% [markdown]
# #### 4.6 Closing connection

# %%
conn_rds.close()

# %% [markdown]
# ### 5. Transformation

# %% [markdown]
# #### 5.1 Selecting subsets of each dataframe

# %%
# Kamus pemetaan bulan dalam bahasa Indonesia
month_mapping = {
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',
    5: 'Mei', 6: 'Jun', 7: 'Jul', 8: 'Agu',
    9: 'Sep', 10: 'Okt', 11: 'Nov', 12: 'Des'
}

# Ekstraksi tahun, bulan, dan hari
users_df['tahun'] = users_df['created_at'].dt.year
users_df['bulan'] = users_df['created_at'].dt.month.map(month_mapping)
users_df['tanggal'] = users_df['created_at'].dt.day
users_df['tanggallengkap'] = pd.to_datetime(users_df['created_at'].dt.date)

dim_destinations = destinations_df[['id', 'name', 'description', 'open_time', 'close_time', 'entry_price', 'longitude', 'latitude', 'visit_count']]
dim_routes = routes_df[['id', 'name', 'start_longitude', 'start_latitude', 'price']]
dim_route_details = route_details_df[['id', 'longitude', 'latitude', 'duration', 'order', 'visit_start', 'visit_end']]
dim_users = users_df[['id', 'email', 'username', 'fullname', 'phone_number', 'gender', 'city', 'province', 'tahun', 'bulan', 'tanggal', 'tanggallengkap']]

# %% [markdown]
# #### 5.2 destinations dimension

# %%
dim_destinations
# Out:
#                                        id                         name  \
# 0    00319825-e81b-4a93-bf9a-eef836ccf6ce  Keraton Kasunanan Surakarta
# 1    005e32da-f5fb-405c-9772-f6424c011fac         Desa Wisata Kasongan
# 2    01b8da3a-3987-4976-9ae7-46d6b8eacee5          Saung Angklung Udjo
# 3    01ccaac9-97fe-42e1-8034-bc0c02471692    Museum Etnografi Sendawar
# 4    02834099-7ce7-44b9-8b27-e4db38f062bd                Danau Limboto
# ..                                    ...                          ...
# 428  fbee819e-2b7b-44fe-8d5a-74dd345cea0e                  Danau Tahai
# 429  fc780065-0848-467b-9625-9c24ecd2e9c2                  Pantai Maaf
# 430  fde8748a-2ec0-4211-89e5-12f3d63db81b          Piaynemo Raja Ampat
# 431  fe1ebfe5-365f-4893-aa36-91e380bb2011           Wisata Pantai Gedo
# 432  ff779270-ee68-46cc-929c-cdd67d328772                 Danau Emfote
#
#                                            description open_time close_time  \
# 0    Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 1    Desa yang terkenal dengan kerajinan gerabah da...      8:00      17:00
# 2    Saung Angklung Udjo adalah pusat Seni dan Buda...      8:00      17:00
# 3    Museum Etnografi Sendawar merupakan museum per...      9:00      18:00
# 4    Danau ini terletak di Kecamatan Limboto, tepat...      0:00      23:59
# ..                                                 ...       ...        ...
# 428  Di kawasan objek wisata Danau Tahai ini terdap...      0:00      23:59
# 429  Pantai Maaf menawarkan perairan yang damai den...      6:00      18:00
# 430  Piaynemo adalah salah satu ikon wisata di Raja...     10:00      17:00
# 431  Wisata Pantai Gedo adalah destinasi pantai ind...      6:00      18:00
# 432  Danau Emfote adalah salah satu destinasi alam ...      0:00      23:59
#
#      entry_price   longitude  latitude  visit_count
# 0        20000.0  110.827903 -7.577736          293
# 1            0.0  110.337978 -7.845291          243
# 2       120000.0  107.654684 -6.897701          203
# 3         5000.0  115.701909 -0.232651          134
# 4            0.0  123.007543  0.577025          219
# ..           ...         ...       ...          ...
# 428          0.0  113.783202 -2.027312          136
# 429      10000.0  135.496749 -3.360245          163
# 430     150000.0  130.270813 -0.564206          123
# 431      15000.0  135.546550 -3.309413          300
# 432      20000.0  140.539693 -2.660878          208
#
# [433 rows x 9 columns]

# %% [markdown]
# #### 5.3 routes dimension

# %%
dim_routes
# Out:
#                                        id                name  \
# 0    0170287c-00ad-4c97-a873-7ef6e13be7fb                ruut
# 1    02dcc9f2-1970-4a36-9031-b434a618e1a7              asdasd
# 2    02f6854d-1b57-4079-a2e3-394e9f037bb4  Liburan ke Bandung
# 3    0458f0ec-4bbe-4950-99ad-afd5f48762d3       bandung day 1
# 4    08aa6f3c-acb9-424d-8a74-7ab2605c9965                 asd
# ..                                    ...                 ...
# 118  f7eb9190-deb0-4d46-9e3e-6e68a886857c               ruyut
# 119  fca75cfb-7cee-46bf-b505-68ecd0a52a11              ruutte
# 120  fcd77473-4635-478f-9aff-62a1e98ef274              ruutte
# 121  ff93ad6e-0e2a-484b-87eb-ad57fb75a6d7                ruut
# 122  ffe5b436-6552-44b5-931b-3fedf7185b9a                ruut
#
#      start_longitude  start_latitude      price
# 0         112.648475       -7.928018  3500000.0
# 1         112.648475       -7.928018    30000.0
# 2         107.620761       -6.916096   200000.0
# 3        -122.084000       37.421998   200000.0
# 4         112.648475       -7.928018   500000.0
# ..               ...             ...        ...
# 118        21.000000       -7.966620    50000.0
# 119        21.000000       -7.966620    50000.0
# 120        21.000000       -7.966620    50000.0
# 121        21.000000       -7.966620    50000.0
# 122       112.648475       -7.928018    85000.0
#
# [123 rows x 5 columns]

# %% [markdown]
# #### 5.4 route_details dimension

# %%
dim_route_details['visit_start'] = dim_route_details['visit_start'].astype(str)
dim_route_details['visit_end'] = dim_route_details['visit_end'].astype(str)
dim_route_details
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_24800\476546220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dim_route_details['visit_start'] = dim_route_details['visit_start'].astype(str)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_24800\476546220.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dim_route_details['visit_end'] = dim_route_details['visit_end'].astype(str)
#                                        id   longitude  latitude  duration  \
# 0    01ba3f24-769f-4d01-a8a2-4bb88355fba5  107.576041 -6.798706     64800
# 1    01d3401f-0e80-4181-b31f-2399ba20d5ff  100.217877 -0.353873     97920
# 2    0376514c-37af-49da-b9b5-1f934bcc0827  107.207205 -7.018241     10800
# 3    03dab2c8-7290-41e2-a07e-916824d12ca8   96.996653  4.592379     21600
# 4    04b5cb11-69e2-4175-9fb4-3fc45e71c3b8  106.889957 -6.301783     18000
# ..                                    ...         ...       ...       ...
# 182  f4449f3e-995d-458b-9ed1-a94e338cc1ac  103.159275 -4.022511      2700
# 183  f5009d18-3e42-4832-9f62-be7d5fdb25e8  116.461640 -8.410276      5400
# 184  f6054c5d-d8a7-4800-96f3-e5c07fcf5af2  114.573132 -3.293217      1200
# 185  fc33e4ac-09ee-4192-bf1b-1fffc89fa09c  100.192011 -0.305623     25200
# 186  ffa44445-cf56-44ae-a25b-c6ebbc60fabf  107.654684 -6.897701      5400
#
#      order      visit_start        visit_end
# 0        1  0 days 09:00:00  0 days 10:30:00
# 1        1  0 days 11:30:00  0 days 13:00:00
# 2        2  0 days 11:30:00  0 days 12:30:00
# 3        1  0 days 11:30:00  0 days 15:00:00
# 4        1  0 days 16:30:00  0 days 18:00:00
# ..     ...              ...              ...
# 182      2  0 days 11:00:00  0 days 11:45:00
# 183      1  0 days 07:00:00  0 days 14:00:00
# 184      2  0 days 14:00:00  0 days 15:30:00
# 185      1  0 days 10:00:00  0 days 11:00:00
# 186      3  0 days 15:00:00  0 days 16:30:00
#
# [187 rows x 7 columns]

# %% [markdown]
# #### 5.5 users dimension

# %%
dim_users
# Out:
#                                        id                        email  \
# 0    00862788-5ded-4065-8275-2569748f64aa       xifihi49190@huleos.com
# 1    00bddbb8-8e7d-46ab-acfc-aab981c1ada1  irsyadyazidsyafiq@gmail.com
# 2    03d7240b-3e9b-4105-ac93-a926b752bb81             shuu@example.com
# 3    0483c5ae-046a-403a-a656-db920635396b      johndoe2345@example.com
# 4    05d6e970-851b-4a8d-8869-587ebe5273cd           ulfiizza@gmail.com
# ..                                    ...                          ...
# 175  fa95b90d-41a8-44fe-aea8-e3b1553532c8      puterisalsaa8@gmail.com
# 176  fc21e23a-ca8c-4cf9-8c5d-f1a56b431022             xhyeni@gmail.com
# 177  fc9e86d9-e3ba-42eb-a46c-16ba07dfeb74        tajoli5069@javnoi.com
# 178  fd13566c-bd12-4088-8537-2a52dbdca23b        Nausicaa5@example.com
# 179  fd84765b-865a-4c9b-9cc5-93ca3836e6de     zerenitymods01@gmail.com
#
#          username         fullname   phone_number  gender       city  \
# 0    testverify10         John Doe   081234567891
# 1    yazid.syafiq    Yazid Syafiq    081393984849    Pria  Pringsewu
# 2          paimon     nama_lengkap   081234567890  Wanita     Jaksel
# 3     johndoe2443         John Doe   081234567891
# 4            ulfi        ulfi izza   089123456789  Wanita     malang
# ..            ...              ...            ...     ...        ...
# 175      inisalsa  Salsa Maulidina    08115122238
# 176        xhyeni    xhyeni ananda   086182836712  Wanita     Malang
# 177  testverfiy25      Test Verify    08123456789
# 178     Nausicaa5         John Doe   081234567891
# 179        rayhan         rayhanqr  0895320511122
#
#        province  tahun bulan  tanggal tanggallengkap
# 0                 2024   Feb       28     2024-02-28
# 1       Lampung   2024   Mei       18     2024-05-18
# 2       Jakarta   2024   Jun       16     2024-06-16
# 3          None   2024   Mar       15     2024-03-15
# 4    jawa timur   2024   Feb       16     2024-02-16
# ..          ...    ...   ...      ...            ...
# 175               2024   Feb        6     2024-02-06
# 176  Jawa Timur   2024   Jan       28     2024-01-28
# 177               2024   Jan       26     2024-01-26
# 178               2024   Feb       17     2024-02-17
# 179               2024   Jun       10     2024-06-10
#
# [180 rows x 12 columns]

# %% [markdown]
# #### 5.6 routes_fact

# %%
# merging dataframes
merged_df = pd.merge(routes_df, route_details_df, left_on='id', right_on='route_id', suffixes=('_routes', '_route_details'))
merged_df = pd.merge(merged_df, users_df, left_on='user_id', right_on='id', suffixes=('_routes', '_users'))
merged_df = pd.merge(merged_df, destinations_df, left_on='destination_id', right_on='id', suffixes=('_routes_users', '_destinations'))

# Pilih subset kolom
routes_fact = merged_df[['id_routes', 'user_id', 'id_route_details', 'id_destinations']]

# renaming some of columns name
routes_fact = routes_fact.rename(columns={"id_routes": "route_id", 
                                          "id_route_details": "route_details_id", 
                                          "id_destinations": "destinations_id"})

# adding user_count and route_count columns
routes_fact['user_count'] = 1
routes_fact['route_count'] = 1

# Menghitung total destinations untuk setiap route_id
routes_fact['total_destination'] = routes_fact.groupby('route_id')['destinations_id'].transform('count')

# display the dataframe
routes_fact
# Out:
#                                  route_id  \
# 0    0170287c-00ad-4c97-a873-7ef6e13be7fb
# 1    11ff1820-7fa5-4be9-94ae-c46759afa1dc
# 2    134eba7b-2875-4728-b8fa-658b0ec3c3e4
# 3    1566f86e-80a4-4cd4-b65c-936881e08966
# 4    30c1f899-2b4e-484a-8434-ac435f51f961
# ..                                    ...
# 182  a246937b-4c7c-46d9-851d-cae90f527b38
# 183  bceb830e-f896-41b5-8539-d0097f784f04
# 184  bceb830e-f896-41b5-8539-d0097f784f04
# 185  cc53f754-4d5c-4bdd-b9d9-9cf44ba8b187
# 186  cc53f754-4d5c-4bdd-b9d9-9cf44ba8b187
#
#                                   user_id  \
# 0    16c77b92-1cb6-476e-8b58-dbffbb0ec8b9
# 1    16c77b92-1cb6-476e-8b58-dbffbb0ec8b9
# 2    16c77b92-1cb6-476e-8b58-dbffbb0ec8b9
# 3    16c77b92-1cb6-476e-8b58-dbffbb0ec8b9
# 4    16c77b92-1cb6-476e-8b58-dbffbb0ec8b9
# ..                                    ...
# 182  30df1cf7-25c2-4d7c-9f25-74634c63f177
# 183  30df1cf7-25c2-4d7c-9f25-74634c63f177
# 184  30df1cf7-25c2-4d7c-9f25-74634c63f177
# 185  36dbd1bf-3aba-4c54-bb44-382fb58e9097
# 186  36dbd1bf-3aba-4c54-bb44-382fb58e9097
#
#                          route_details_id  \
# 0    29736670-002b-4f6a-8964-ecdb11bd688b
# 1    71c5f7f0-0d75-49ed-974a-cb79425f61b1
# 2    94c8dcc2-0069-4a1f-b447-56c6a1d8e665
# 3    eac8b16c-38e6-44e2-b523-2c9d7429fe26
# 4    7bb7fd1a-a609-456d-ad59-ec9c6c09b88d
# ..                                    ...
# 182  b2c11642-01b2-4d7e-9dce-9bd669c56fef
# 183  0e2b9226-70a6-45e3-86ee-f3352ab4e559
# 184  32a45a19-ca30-4fdd-987d-755f3453ac9a
# 185  4cc95711-2aee-488b-ab93-2541d0ef077a
# 186  f6054c5d-d8a7-4800-96f3-e5c07fcf5af2
#
#                           destinations_id  user_count  route_count  \
# 0    6a724317-15aa-4890-ab1f-7758106ad6d2           1            1
# 1    6a724317-15aa-4890-ab1f-7758106ad6d2           1            1
# 2    6a724317-15aa-4890-ab1f-7758106ad6d2           1            1
# 3    6a724317-15aa-4890-ab1f-7758106ad6d2           1            1
# 4    6a724317-15aa-4890-ab1f-7758106ad6d2           1            1
# ..                                    ...         ...          ...
# 182  d6a99094-4263-4982-9fd3-e424ce1021cf           1            1
# 183  859934c8-6dbb-4cb0-9222-5de58d353ad6           1            1
# 184  fde8748a-2ec0-4211-89e5-12f3d63db81b           1            1
# 185  bc078485-80b6-4aa9-8ebc-8dea650ba673           1            1
# 186  eb8122b0-9f90-46f1-9bd2-5366fe0a40c7           1            1
#
#      total_destination
# 0                    1
# 1                    2
# 2                    1
# 3                    2
# 4                    1
# ..                 ...
# 182                  3
# 183                  2
# 184                  2
# 185                  2
# 186                  2
#
# [187 rows x 7 columns]

# %% [markdown]
# ### 6. Load

# %% [markdown]
# #### load _to_gbq function below is used to load extract data from a dataframe into a table in google big query

# %%
def load_to_gbq(credentials, project_id, dataset_id, table_names, dataframes):
   for df, table_name in zip(dataframes, table_names):
      table_full_id = f'{project_id}.{dataset_id}.{table_name}'
      to_gbq(df, table_full_id, project_id=project_id, if_exists='replace', credentials=credentials)
      print(f'Table {table_name} loaded successfully!')

# %% [markdown]
# #### 6.1 Load to Big Query

# %%
credentials = service_account.Credentials.from_service_account_file(google_application_credentials)

dfs = [dim_destinations, dim_routes, dim_route_details, dim_users, routes_fact]
tables = ['dim_destinations', 'dim_routes', 'dim_route_details', 'dim_users', 'routes_fact']

load_to_gbq(credentials, project_id, dataset_id, tables, dfs)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_destinations loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_routes loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_route_details loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_users loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table routes_fact loaded successfully!
