# %% [markdown]
# ### 1. Install Library

# %%
# %pip install pandas-gbq google-cloud-bigquery
# %pip install pandas-gbq google-auth google-auth-oauthlib

# %% [markdown]
# ### 2. Import Library

# %%
import pandas as pd
import numpy as np

import mysql.connector

from google.oauth2 import service_account
from google.cloud import bigquery
import pandas_gbq
from pandas_gbq import to_gbq

import os
from dotenv import load_dotenv

# %% [markdown]
# ### 3. Database Configuration

# %%
# Load konfigurasi dari .env
load_dotenv()

# MySQL configurations
rds_host = os.getenv('RDS_HOST')
rds_dbname = os.getenv('RDS_DBNAME')
rds_user = os.getenv('RDS_USER')
rds_password = os.getenv('RDS_PASSWORD')

# Google Cloud configurations
project_id = os.getenv('GOOGLE_CLOUD_PROJECT_ID')
dataset_id = os.getenv('GOOGLE_CLOUD_DATASET_ID')
google_application_credentials = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = google_application_credentials

# Koneksi ke MySQL di Amazon RDS
conn_rds = mysql.connector.connect(
    host=rds_host,
    database=rds_dbname,
    user=rds_user,
    password=rds_password
)

# %% [markdown]
# ### 4. Extract

# %% [markdown]
# #### table_to_df function below is used to extract data from a table and convert it into a dataframe

# %%
def table_to_df(table_name):
   query = f"SELECT * FROM {table_name}"
   df = pd.read_sql_query(query, conn_rds)
   return df

# %% [markdown]
# #### 4.1 Converting data from tables to dataframes

# %%
destinations_df = table_to_df('destinations')
routes_df = table_to_df('routes')
route_details_df = table_to_df('route_details')
users_df = table_to_df('users')
# Out:
# C:\Users\MATRIX COMPUTER\AppData\Local\Temp\ipykernel_17808\1223067120.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn_rds)

# %% [markdown]
# #### 4.2 destinations dataframe

# %%
destinations_df
# Out:
#                                        id  \
# 0    00319825-e81b-4a93-bf9a-eef836ccf6ce
# 1    005e32da-f5fb-405c-9772-f6424c011fac
# 2    01b8da3a-3987-4976-9ae7-46d6b8eacee5
# 3    01ccaac9-97fe-42e1-8034-bc0c02471692
# 4    02834099-7ce7-44b9-8b27-e4db38f062bd
# ..                                    ...
# 323  fbee819e-2b7b-44fe-8d5a-74dd345cea0e
# 324  fc780065-0848-467b-9625-9c24ecd2e9c2
# 325  fde8748a-2ec0-4211-89e5-12f3d63db81b
# 326  fe1ebfe5-365f-4893-aa36-91e380bb2011
# 327  ff779270-ee68-46cc-929c-cdd67d328772
#
#                               category_id                         name  \
# 0    eb77b590-b255-4ea1-b11a-d445a259ac62  Keraton Kasunanan Surakarta
# 1    eb77b590-b255-4ea1-b11a-d445a259ac62         Desa Wisata Kasongan
# 2    eb77b590-b255-4ea1-b11a-d445a259ac62          Saung Angklung Udjo
# 3    eb77b590-b255-4ea1-b11a-d445a259ac62    Museum Etnografi Sendawar
# 4    eb77b590-b255-4ea1-b11a-d445a259ac61                Danau Limboto
# ..                                    ...                          ...
# 323  eb77b590-b255-4ea1-b11a-d445a259ac61                  Danau Tahai
# 324  eb77b590-b255-4ea1-b11a-d445a259ac61                  Pantai Maaf
# 325  eb77b590-b255-4ea1-b11a-d445a259ac61          Piaynemo Raja Ampat
# 326  eb77b590-b255-4ea1-b11a-d445a259ac61           Wisata Pantai Gedo
# 327  eb77b590-b255-4ea1-b11a-d445a259ac61                 Danau Emfote
#
#                                            description open_time close_time  \
# 0    Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 1    Desa yang terkenal dengan kerajinan gerabah da...      8:00      17:00
# 2    Saung Angklung Udjo adalah pusat Seni dan Buda...      8:00      17:00
# 3    Museum Etnografi Sendawar merupakan museum per...      9:00      18:00
# 4    Danau ini terletak di Kecamatan Limboto, tepat...      0:00      23:59
# ..                                                 ...       ...        ...
# 323  Di kawasan objek wisata Danau Tahai ini terdap...      0:00      23:59
# 324  Pantai Maaf menawarkan perairan yang damai den...      6:00      18:00
# 325  Piaynemo adalah salah satu ikon wisata di Raja...     10:00      17:00
# 326  Wisata Pantai Gedo adalah destinasi pantai ind...      6:00      18:00
# 327  Danau Emfote adalah salah satu destinasi alam ...      0:00      23:59
#
#      entry_price   longitude  latitude  visit_count          created_at  \
# 0        20000.0  110.827903 -7.577736          290 2024-06-11 08:28:33
# 1            0.0  110.337978 -7.845291          243 2024-06-11 08:28:27
# 2       120000.0  107.654684 -6.897701          202 2024-06-11 08:28:33
# 3         5000.0  115.701909 -0.232651          134 2024-06-11 08:28:20
# 4            0.0  123.007543  0.577025          219 2024-06-11 08:28:21
# ..           ...         ...       ...          ...                 ...
# 323          0.0  113.783202 -2.027312          136 2024-06-11 08:28:19
# 324      10000.0  135.496749 -3.360245          163 2024-06-11 08:28:32
# 325     150000.0  130.270813 -0.564206          123 2024-06-11 08:28:32
# 326      15000.0  135.546550 -3.309413          299 2024-06-11 08:28:32
# 327      20000.0  140.539693 -2.660878          207 2024-06-11 08:28:30
#
#              updated_at deleted_at
# 0   2024-06-15 16:22:11        NaT
# 1   2024-06-13 13:00:10        NaT
# 2   2024-06-15 14:47:11        NaT
# 3   2024-06-13 16:58:21        NaT
# 4   2024-06-15 14:26:21        NaT
# ..                  ...        ...
# 323 2024-06-11 08:28:19        NaT
# 324 2024-06-11 08:28:32        NaT
# 325 2024-06-11 08:28:32        NaT
# 326 2024-06-11 08:28:32        NaT
# 327 2024-06-11 08:28:30        NaT
#
# [328 rows x 13 columns]

# %% [markdown]
# #### 4.3 routes dataframe

# %%
routes_df
# Out:
#                                       id  \
# 0   0308d6d2-d28b-42d0-ad28-e64fd96bb2fd
# 1   12d9132d-487f-456c-8903-583969dc6a3b
# 2   179665db-dfba-4d10-8371-29d2ce169cc2
# 3   2c1fe7b4-9074-4729-afe7-4b474d6b274d
# 4   2d128871-2825-4e44-90dc-92567df931f3
# 5   3e9009a5-8edd-421f-9c2c-0740bfde93f8
# 6   3fbff38a-5e74-48a7-bad1-65fc58035436
# 7   cdf5c8ef-0401-4e31-926a-c102b88ea1f9
# 8   da386bd6-e1b7-4129-b3a6-e75d24594c1a
# 9   e32f9896-3cd7-423b-8f36-0df92f4dcde4
# 10  e55eac90-521d-4cc5-879a-d208870f0275
# 11  ed23be94-c0c5-40bf-a017-2ee831ab919e
# 12  ef234ca4-f0d4-4ee1-a7ae-1199f72a2d7f
# 13  f1d60ba6-e689-4041-a11c-1a5a8cf0c793
# 14  f8fad44d-e5b1-4a3b-939e-1955bf9f7c67
#
#                                  user_id city_id         name start_location  \
# 0   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d
# 121  fd13566c-bd12-4088-8537-2a52dbdca23b        Nausicaa5@example.com
# 122  fd84765b-865a-4c9b-9cc5-93ca3836e6de     zerenitymods01@gmail.com
#
#                                               password      username  \
# 0    $2a$10$X4GUlWtLjn/8M2cT7mOm/eD2nicI91W3mqm3mEI...  testverify10
# 1    $2a$10$HcMceoyuqQLLmjNKny2peOLz.pxxT563Mua2u1n...  yazid.syafiq
# 2    $2a$10$NvsLJLtnk.IW7gdbkOwK8Ob7uuAADw4o53ctlZW...        paimon
# 3    $2a$10$Dxg27rgrHy1bZPiD0jNI8uInxr/duxnf3QEH8IS...   johndoe2443
# 4    $2a$10$PcldSAzZwvZJecyKpa4WOu3AoaSXQnYpJ/5ujY3...          ulfi
# ..                                                 ...           ...
# 118  $2a$10$.FKubUMci00v1frZk5.q9e.R74d4v4mlTG.6V/v...   testverify4
# 119  $2a$10$fkklkqERHa.hDRZxlPHhp.dzWPhwSchFLKzC4y0...      inisalsa
# 120  $2a$10$D5rUZTz5z2SkdRJMeogJLODp2Xp9kHSLTVtNTrC...  testverfiy25
# 121  $2a$10$mR0l7hjnGtU6PF9V1LHTFerCZXqK.w7vBy.M.h0...     Nausicaa5
# 122  $2a$10$/lQPZ5g99QUv/TiK20NenOQFCBKEFaiVFMqX5eN...        rayhan
#
#                 fullname                bio   phone_number  \
# 0               John Doe                      081234567891
# 1    Yazid Syafiq Irsyad  Manusia Biasa Aja   081393984849
# 2           nama_lengkap                bio   081234567890
# 3               John Doe                      081234567891
# 4              ulfi izza                      089123456789
# ..                   ...                ...            ...
# 118             John Doe                      081234567891
# 119      Salsa Maulidina                       08115122238
# 120          Test Verify                       08123456789
# 121             John Doe                      081234567891
# 122             rayhanqr                     0895320511122
#
#                                      profile_image_url     gender    city  \
# 0
# 1                                                            Pria
# 2                                              img.jpg       pria  Jaksel
# 3
# 4    https://res.cloudinary.com/alta-minpro/image/u...  Perempuan  malang
# ..                                                 ...        ...     ...
# 118
# 119                                               None
# 120
# 121                                               None
# 122                                               None
#
#           email_verified_at              created_at              updated_at  \
# 0                       NaT 2024-05-27 15:26:01.704 2024-05-27 15:26:01.704
# 1   2024-05-31 11:59:19.353 2024-05-31 11:58:43.404 2024-06-15 14:25:36.089
# 2                       NaT 2024-05-28 06:43:29.804 2024-06-05 14:44:35.107
# 3                       NaT 2024-05-25 15:12:44.106 2024-05-25 15:12:44.106
# 4                       NaT 2024-06-13 03:35:00.083 2024-06-16 07:39:34.906
# ..                      ...                     ...                     ...
# 118                     NaT 2024-05-27 14:11:13.805 2024-05-27 14:11:13.805
# 119 2024-06-10 12:12:21.233 2024-06-10 12:11:56.116 2024-06-10 12:12:23.104
# 120 2024-05-28 07:16:51.573 2024-05-28 07:16:28.803 2024-05-28 07:16:51.576
# 121                     NaT 2024-06-12 07:00:16.507 2024-06-12 07:00:16.507
# 122 2024-06-16 09:23:46.538 2024-06-16 09:21:23.905 2024-06-16 09:23:49.107
#
#                  deleted_at    province  \
# 0   2024-06-14 09:16:42.952
# 1                       NaT
# 2                       NaT     Jakarta
# 3   2024-06-05 14:46:44.405        None
# 4                       NaT  jawa timur
# ..                      ...         ...
# 118                     NaT
# 119                     NaT
# 120                     NaT
# 121                     NaT
# 122                     NaT
#
#                                          refresh_token
# 0                                                 None
# 1    eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJZCI6I...
# 2
# 3                                                 None
# 4
# ..                                                 ...
# 118                                               None
# 119  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJZCI6I...
# 120                                               None
# 121
# 122  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJZCI6I...
#
# [123 rows x 16 columns]

# %% [markdown]
# #### 4.6 Closing connection

# %%
conn_rds.close()

# %% [markdown]
# ### 5. Transformation

# %% [markdown]
# #### 5.1 Selecting subsets of each dataframe

# %%
users_df['tahun'] = users_df['created_at'].dt.year
users_df['bulan'] = users_df['created_at'].dt.month
users_df['tanggal'] = users_df['created_at'].dt.day
users_df['tanggallengkap'] = pd.to_datetime(users_df['created_at'].dt.date)

dim_destinations = destinations_df[['id', 'name', 'description', 'open_time', 'close_time', 'entry_price', 'longitude', 'latitude', 'visit_count']]
dim_routes = routes_df[['id', 'name', 'start_longitude', 'start_latitude', 'price']]
dim_route_details = route_details_df[['id', 'longitude', 'latitude', 'duration', 'order', 'visit_start', 'visit_end']]
dim_users = users_df[['id', 'email', 'username', 'fullname', 'phone_number', 'gender', 'city', 'province', 'tahun', 'bulan', 'tanggal', 'tanggallengkap']]

# %% [markdown]
# #### 5.2 destinations dimension

# %%
dim_destinations
# Out:
#                                        id                         name  \
# 0    00319825-e81b-4a93-bf9a-eef836ccf6ce  Keraton Kasunanan Surakarta
# 1    005e32da-f5fb-405c-9772-f6424c011fac         Desa Wisata Kasongan
# 2    01b8da3a-3987-4976-9ae7-46d6b8eacee5          Saung Angklung Udjo
# 3    01ccaac9-97fe-42e1-8034-bc0c02471692    Museum Etnografi Sendawar
# 4    02834099-7ce7-44b9-8b27-e4db38f062bd                Danau Limboto
# ..                                    ...                          ...
# 323  fbee819e-2b7b-44fe-8d5a-74dd345cea0e                  Danau Tahai
# 324  fc780065-0848-467b-9625-9c24ecd2e9c2                  Pantai Maaf
# 325  fde8748a-2ec0-4211-89e5-12f3d63db81b          Piaynemo Raja Ampat
# 326  fe1ebfe5-365f-4893-aa36-91e380bb2011           Wisata Pantai Gedo
# 327  ff779270-ee68-46cc-929c-cdd67d328772                 Danau Emfote
#
#                                            description open_time close_time  \
# 0    Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 1    Desa yang terkenal dengan kerajinan gerabah da...      8:00      17:00
# 2    Saung Angklung Udjo adalah pusat Seni dan Buda...      8:00      17:00
# 3    Museum Etnografi Sendawar merupakan museum per...      9:00      18:00
# 4    Danau ini terletak di Kecamatan Limboto, tepat...      0:00      23:59
# ..                                                 ...       ...        ...
# 323  Di kawasan objek wisata Danau Tahai ini terdap...      0:00      23:59
# 324  Pantai Maaf menawarkan perairan yang damai den...      6:00      18:00
# 325  Piaynemo adalah salah satu ikon wisata di Raja...     10:00      17:00
# 326  Wisata Pantai Gedo adalah destinasi pantai ind...      6:00      18:00
# 327  Danau Emfote adalah salah satu destinasi alam ...      0:00      23:59
#
#      entry_price   longitude  latitude  visit_count
# 0        20000.0  110.827903 -7.577736          290
# 1            0.0  110.337978 -7.845291          243
# 2       120000.0  107.654684 -6.897701          202
# 3         5000.0  115.701909 -0.232651          134
# 4            0.0  123.007543  0.577025          219
# ..           ...         ...       ...          ...
# 323          0.0  113.783202 -2.027312          136
# 324      10000.0  135.496749 -3.360245          163
# 325     150000.0  130.270813 -0.564206          123
# 326      15000.0  135.546550 -3.309413          299
# 327      20000.0  140.539693 -2.660878          207
#
# [328 rows x 9 columns]

# %% [markdown]
# #### 5.3 routes dimension

# %%
dim_routes
# Out:
#                                       id         name  start_longitude  \
# 0   0308d6d2-d28b-42d0-ad28-e64fd96bb2fd  Route ke 12            12.01
# 1   12d9132d-487f-456c-8903-583969dc6a3b  Route ke 11            12.01
# 2   179665db-dfba-4d10-8371-29d2ce169cc2   Route ke 0            12.01
# 3   2c1fe7b4-9074-4729-afe7-4b474d6b274d   Route ke 9            12.01
# 4   2d128871-2825-4e44-90dc-92567df931f3   Route ke 4            12.01
# 5   3e9009a5-8edd-421f-9c2c-0740bfde93f8  Route ke 13            12.01
# 6   3fbff38a-5e74-48a7-bad1-65fc58035436   Route ke 2            12.01
# 7   cdf5c8ef-0401-4e31-926a-c102b88ea1f9   Route ke 6            12.01
# 8   da386bd6-e1b7-4129-b3a6-e75d24594c1a   Route ke 3            12.01
# 9   e32f9896-3cd7-423b-8f36-0df92f4dcde4   Route ke 5            12.01
# 10  e55eac90-521d-4cc5-879a-d208870f0275  Route ke 10            12.01
# 11  ed23be94-c0c5-40bf-a017-2ee831ab919e   Route ke 7            12.01
# 12  ef234ca4-f0d4-4ee1-a7ae-1199f72a2d7f   Route ke 1            12.01
# 13  f1d60ba6-e689-4041-a11c-1a5a8cf0c793   Route ke 8            12.01
# 14  f8fad44d-e5b1-4a3b-939e-1955bf9f7c67  Route ke 14            12.01
#
#     start_latitude     price
# 0            12.01  100000.0
# 1            12.01  100000.0
# 2            12.01  100000.0
# 3            12.01  100000.0
# 4            12.01  100000.0
# 5            12.01  100000.0
# 6            12.01  100000.0
# 7            12.01  100000.0
# 8            12.01  100000.0
# 9            12.01  100000.0
# 10           12.01  100000.0
# 11           12.01  100000.0
# 12           12.01  100000.0
# 13           12.01  100000.0
# 14           12.01  100000.0

# %% [markdown]
# #### 5.4 route_details dimension

# %%
dim_route_details['visit_start'] = dim_route_details['visit_start'].astype(str)
dim_route_details['visit_end'] = dim_route_details['visit_end'].astype(str)
dim_route_details
# Out:
# C:\Users\MATRIX COMPUTER\AppData\Local\Temp\ipykernel_17808\476546220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dim_route_details['visit_start'] = dim_route_details['visit_start'].astype(str)
# C:\Users\MATRIX COMPUTER\AppData\Local\Temp\ipykernel_17808\476546220.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   
# 122  fd84765b-865a-4c9b-9cc5-93ca3836e6de     zerenitymods01@gmail.com
#
#          username             fullname   phone_number     gender    city  \
# 0    testverify10             John Doe   081234567891
# 1    yazid.syafiq  Yazid Syafiq Irsyad   081393984849       Pria
# 2          paimon         nama_lengkap   081234567890       pria  Jaksel
# 3     johndoe2443             John Doe   081234567891
# 4            ulfi            ulfi izza   089123456789  Perempuan  malang
# ..            ...                  ...            ...        ...     ...
# 118   testverify4             John Doe   081234567891
# 119      inisalsa      Salsa Maulidina    08115122238
# 120  testverfiy25          Test Verify    08123456789
# 121     Nausicaa5             John Doe   081234567891
# 122        rayhan             rayhanqr  0895320511122
#
#        province  tahun  bulan  tanggal tanggallengkap
# 0                 2024      5       27     2024-05-27
# 1                 2024      5       31     2024-05-31
# 2       Jakarta   2024      5       28     2024-05-28
# 3          None   2024      5       25     2024-05-25
# 4    jawa timur   2024      6       13     2024-06-13
# ..          ...    ...    ...      ...            ...
# 118               2024      5       27     2024-05-27
# 119               2024      6       10     2024-06-10
# 120               2024      5       28     2024-05-28
# 121               2024      6       12     2024-06-12
# 122               2024      6       16     2024-06-16
#
# [123 rows x 12 columns]

# %% [markdown]
# #### 5.6 routes_fact

# %%
# merging dataframes
merged_df = pd.merge(routes_df, route_details_df, left_on='id', right_on='route_id', suffixes=('_routes', '_route_details'))
merged_df = pd.merge(merged_df, users_df, left_on='user_id', right_on='id', suffixes=('_routes', '_users'))
merged_df = pd.merge(merged_df, destinations_df, left_on='destination_id', right_on='id', suffixes=('_routes_users', '_destinations'))

# selecting subset
routes_fact = merged_df[['id_routes', 'user_id', 'id_route_details', 'id_destinations']]

# renaming some of columns name
routes_fact = routes_fact.rename(columns={"id_routes": "route_id", 
                                          "id_route_details": "route_details_id", 
                                          "id_destinations": "destinations_id"})

# adding user_count and route_count columns
routes_fact['user_count'] = 1
routes_fact['route_count'] = 1

# display the dataframe
routes_fact
# Out:
#                                 route_id  \
# 0   0308d6d2-d28b-42d0-ad28-e64fd96bb2fd
# 1   12d9132d-487f-456c-8903-583969dc6a3b
# 2   179665db-dfba-4d10-8371-29d2ce169cc2
# 3   2c1fe7b4-9074-4729-afe7-4b474d6b274d
# 4   2d128871-2825-4e44-90dc-92567df931f3
# 5   3e9009a5-8edd-421f-9c2c-0740bfde93f8
# 6   3fbff38a-5e74-48a7-bad1-65fc58035436
# 7   cdf5c8ef-0401-4e31-926a-c102b88ea1f9
# 8   da386bd6-e1b7-4129-b3a6-e75d24594c1a
# 9   e32f9896-3cd7-423b-8f36-0df92f4dcde4
# 10  e55eac90-521d-4cc5-879a-d208870f0275
# 11  ed23be94-c0c5-40bf-a017-2ee831ab919e
# 12  ef234ca4-f0d4-4ee1-a7ae-1199f72a2d7f
# 13  f1d60ba6-e689-4041-a11c-1a5a8cf0c793
# 14  f8fad44d-e5b1-4a3b-939e-1955bf9f7c67
#
#                                  user_id  \
# 0   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 1   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 2   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 3   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 4   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 5   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 6   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 7   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 8   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 9   a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 10  a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 11  a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 12  a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 13  a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
# 14  a8bddfb7-075a-4e3e-bfb0-c4a5f9d270d2
#
#                         route_details_id  \
# 0   9bc4a709-4806-46d1-a994-31cc5615e56c
# 1   dbfe7fcd-b57f-4a03-b448-f875b0f300b9
# 2   92b83aa1-a21c-4aae-9c05-db37202bc473
# 3   457ad80a-f4ff-48cd-9dfb-d8220612ec33
# 4   4706fb68-cd5c-4254-9d42-a29376a8b8c0
# 5   43025319-7917-4bd9-8a6a-bf94fbccb2f0
# 6   d4f67fdc-0f83-412a-8a3d-29d806de3b20
# 7   f4807627-2a0f-4510-b6be-99d9765db504
# 8   b5633440-68b7-4384-acf6-8b0e6dd48164
# 9   0fd4b579-711a-4811-a8ec-0fcefe43504e
# 10  3edc771b-a2fc-485d-9462-501b6dad15c3
# 11  e95d3985-3508-4405-a6d7-9e9d5106b0a6
# 12  57ba59a7-f151-4a4f-b1ea-60ba9c464944
# 13  d37a5542-0300-4027-b006-4e28d04f4205
# 14  f4f9cfed-0a58-4cf9-b29d-fcdf9716a126
#
#                          destinations_id  user_count  route_count
# 0   427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 1   427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 2   427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 3   427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 4   427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 5   427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 6   427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 7   427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 8   427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 9   427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 10  427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 11  427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 12  427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 13  427f1b85-ff48-4116-8b11-288c764351ca           1            1
# 14  427f1b85-ff48-4116-8b11-288c764351ca           1            1

# %% [markdown]
# ### 6. Load

# %% [markdown]
# #### load _to_gbq function below is used to load extract data from a dataframe into a table in google big query

# %%
def load_to_gbq(credentials, project_id, dataset_id, table_names, dataframes):
   for df, table_name in zip(dataframes, table_names):
      table_full_id = f'{project_id}.{dataset_id}.{table_name}'
      to_gbq(df, table_full_id, project_id=project_id, if_exists='replace', credentials=credentials)
      print(f'Table {table_name} loaded successfully!')

# %% [markdown]
# #### 6.1 Load to Big Query

# %%
credentials = service_account.Credentials.from_service_account_file(google_application_credentials)

dfs = [dim_destinations, dim_routes, dim_route_details, dim_users, routes_fact]
tables = ['dim_destinations', 'dim_routes', 'dim_route_details', 'dim_users', 'routes_fact']

load_to_gbq(credentials, project_id, dataset_id, tables, dfs)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_destinations loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_routes loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_route_details loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_users loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table routes_fact loaded successfully!
