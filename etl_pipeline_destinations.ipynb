# %% [markdown]
# ### 1. Install Library

# %%
# %pip install pandas mysql-connector-python google-cloud-bigquery
# %pip install pandas-gbq

# %% [markdown]
# ### 2. Import Library

# %%
import pandas as pd
import mysql.connector
import os
from pandas_gbq import to_gbq
from google.oauth2 import service_account
from google.cloud import bigquery
from dotenv import load_dotenv

# %% [markdown]
# ### 3. Konfigurasi ke Database

# %%
# Load konfigurasi dari .env
load_dotenv()

# MySQL configurations
rds_host = os.getenv('RDS_HOST')
rds_dbname = os.getenv('RDS_DBNAME')
rds_user = os.getenv('RDS_USER')
rds_password = os.getenv('RDS_PASSWORD')

# Koneksi ke MySQL di Amazon RDS
conn_rds = mysql.connector.connect(
    host=rds_host,
    database=rds_dbname,
    user=rds_user,
    password=rds_password
)

# %% [markdown]
# ### 4. Extract

# %% [markdown]
# #### 4.1 Extract semua tabel dan jadikan dataframe

# %%
# List of tables to extract
tables = [
    'destinations', 'categories', 'destination_facilities', 'facilities',
    'destination_addresses', 'provinces', 'cities', 'subdistricts', 'destination_media', 'admins'
]

# Function to load data from MySQL into pandas DataFrame
def load_table_to_df(table_name):
    query = f"SELECT * FROM {table_name}"
    df = pd.read_sql(query, conn_rds)
    return df

# %% [markdown]
# #### 4.2 Load semua tabel ke Dictionary

# %%
# Load all tables into individual DataFrames and store in a dictionary
dataframes = {}
for table in tables:
    df = load_table_to_df(table)
    dataframes[table] = df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16556\205905624.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn_rds)

# %% [markdown]
# #### 4.3 Close Connection

# %%
# Close the MySQL connection
conn_rds.close()

# %% [markdown]
# #### 4.4 Tampilkan Dataframe destinations

# %%
# Example of accessing and displaying a specific DataFrame
df_destinations = dataframes['destinations']
df_destinations
# Out:
#                                        id  \
# 0    00319825-e81b-4a93-bf9a-eef836ccf6ce
# 1    005e32da-f5fb-405c-9772-f6424c011fac
# 2    01b8da3a-3987-4976-9ae7-46d6b8eacee5
# 3    01ccaac9-97fe-42e1-8034-bc0c02471692
# 4    02834099-7ce7-44b9-8b27-e4db38f062bd
# ..                                    ...
# 427  fbee819e-2b7b-44fe-8d5a-74dd345cea0e
# 428  fc780065-0848-467b-9625-9c24ecd2e9c2
# 429  fde8748a-2ec0-4211-89e5-12f3d63db81b
# 430  fe1ebfe5-365f-4893-aa36-91e380bb2011
# 431  ff779270-ee68-46cc-929c-cdd67d328772
#
#                               category_id                         name  \
# 0    eb77b590-b255-4ea1-b11a-d445a259ac62  Keraton Kasunanan Surakarta
# 1    eb77b590-b255-4ea1-b11a-d445a259ac62         Desa Wisata Kasongan
# 2    eb77b590-b255-4ea1-b11a-d445a259ac62          Saung Angklung Udjo
# 3    eb77b590-b255-4ea1-b11a-d445a259ac62    Museum Etnografi Sendawar
# 4    eb77b590-b255-4ea1-b11a-d445a259ac61                Danau Limboto
# ..                                    ...                          ...
# 427  eb77b590-b255-4ea1-b11a-d445a259ac61                  Danau Tahai
# 428  eb77b590-b255-4ea1-b11a-d445a259ac61                  Pantai Maaf
# 429  eb77b590-b255-4ea1-b11a-d445a259ac61          Piaynemo Raja Ampat
# 430  eb77b590-b255-4ea1-b11a-d445a259ac61           Wisata Pantai Gedo
# 431  eb77b590-b255-4ea1-b11a-d445a259ac61                 Danau Emfote
#
#                                            description open_time close_time  \
# 0    Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 1    Desa yang terkenal dengan kerajinan gerabah da...      8:00      17:00
# 2    Saung Angklung Udjo adalah pusat Seni dan Buda...      8:00      17:00
# 3    Museum Etnografi Sendawar merupakan museum per...      9:00      18:00
# 4    Danau ini terletak di Kecamatan Limboto, tepat...      0:00      23:59
# ..                                                 ...       ...        ...
# 427  Di kawasan objek wisata Danau Tahai ini terdap...      0:00      23:59
# 428  Pantai Maaf menawarkan perairan yang damai den...      6:00      18:00
# 429  Piaynemo adalah salah satu ikon wisata di Raja...     10:00      17:00
# 430  Wisata Pantai Gedo adalah destinasi pantai ind...      6:00      18:00
# 431  Danau Emfote adalah salah satu destinasi alam ...      0:00      23:59
#
#      entry_price   longitude  latitude  visit_count          created_at  \
# 0        20000.0  110.827903 -7.577736          293 2024-06-11 08:28:33
# 1            0.0  110.337978 -7.845291          243 2024-06-11 08:28:27
# 2       120000.0  107.654684 -6.897701          203 2024-06-11 08:28:33
# 3         5000.0  115.701909 -0.232651          134 2024-06-11 08:28:20
# 4            0.0  123.007543  0.577025          219 2024-06-11 08:28:21
# ..           ...         ...       ...          ...                 ...
# 427          0.0  113.783202 -2.027312          136 2024-06-11 08:28:19
# 428      10000.0  135.496749 -3.360245          163 2024-06-11 08:28:32
# 429     150000.0  130.270813 -0.564206          123 2024-06-11 08:28:32
# 430      15000.0  135.546550 -3.309413          300 2024-06-11 08:28:32
# 431      20000.0  140.539693 -2.660878          208 2024-06-11 08:28:30
#
#              updated_at              deleted_at
# 0   2024-06-20 09:53:01 2024-06-20 09:53:01.786
# 1   2024-06-20 09:55:01 2024-06-20 09:55:01.453
# 2   2024-06-20 09:55:14 2024-06-20 09:55:14.647
# 3   2024-06-20 10:00:54 2024-06-20 10:00:54.207
# 4   2024-06-20 10:02:09 2024-06-20 10:02:09.429
# ..                  ...                     ...
# 427 2024-06-11 08:28:19                     NaT
# 428 2024-06-11 08:28:32                     NaT
# 429 2024-06-11 08:28:32                     NaT
# 430 2024-06-23 06:37:28                     NaT
# 431 2024-06-23 11:05:19                     NaT
#
# [432 rows x 13 columns]

# %% [markdown]
# #### 4.5 Tampilkan Dataframe categories

# %%
df_categories = dataframes['categories']
df_categories
# Out:
#                                      id             name  \
# 0  eb77b590-b255-4ea1-b11a-d445a259ac61             Alam
# 1  eb77b590-b255-4ea1-b11a-d445a259ac62  Seni dan Budaya
# 2  eb77b590-b255-4ea1-b11a-d445a259ac63          Sejarah
#
#                                                  url          created_at  \
# 0  https://storage.googleapis.com/categories_url/... 2024-06-23 08:52:09
# 1  https://storage.googleapis.com/categories_url/... 2024-06-23 08:52:09
# 2  https://storage.googleapis.com/categories_url/... 2024-06-23 08:52:09
#
#            updated_at deleted_at
# 0 2024-06-23 08:52:09       None
# 1 2024-06-23 08:52:09       None
# 2 2024-06-23 08:52:09       None

# %% [markdown]
# #### 4.6 Tampilkan Dataframe destination_facilities

# %%
df_destination_facilities = dataframes['destination_facilities']
df_destination_facilities
# Out:
#                                         id  \
# 0     00231d8c-fada-4fe2-b25f-6a7336097219
# 1     00462c88-5922-4a3f-bd75-1a9a0f6bd1f9
# 2     0051aa42-4dec-48d2-91de-59792785c160
# 3     008bf65a-397b-4499-a7fc-31f3177d82d0
# 4     00a620f3-f277-4c9c-a369-399d6cc5aeb2
# ...                                    ...
# 1603  ff95ab6b-5cce-47bb-a656-a14eefa42800
# 1604  ffa08cc6-12fa-45a8-9dfc-e766b713ca2e
# 1605  ffaf87e7-25b7-4a7b-b6c1-207dd9001bed
# 1606  ffc39def-535c-464c-88a3-2804fcd39018
# 1607  ffcda1ea-30c2-421b-8e39-1a40ba5f3499
#
#                             destination_id  \
# 0     4388e724-d0b8-46e0-80bd-1362210b1cc1
# 1     d6b4dcc6-e96e-4652-8587-52c2f5438f59
# 2     0b693f00-1883-4677-a82f-fe76f8e3e781
# 3     ee06a47e-f264-40e9-b9c8-1a3a78492d84
# 4     005e32da-f5fb-405c-9772-f6424c011fac
# ...                                    ...
# 1603  4ce34993-985e-4e27-a31e-4753e6b8ef23
# 1604  6a6cc0c8-cb21-4862-bdac-102cc33824c4
# 1605  f79c2360-d2a8-4c61-aadf-d9966d76cd27
# 1606  682811a3-7034-428c-bcd7-8d9509c55ada
# 1607  963257de-d8bc-4bdd-92dd-3176fcf4ac4d
#
#                                facility_id          created_at  \
# 0     19742db3-9121-4a6f-93dc-50cc051af77e 2024-06-13 18:48:11
# 1     a5990fd0-6d85-4273-bb17-d912b688469c 2024-06-13 18:48:15
# 2     56358ba0-3fad-43f7-9bf6-a7c86f2aec00 2024-06-23 12:39:59
# 3     56358ba0-3fad-43f7-9bf6-a7c86f2aec00 2024-06-13 18:48:14
# 4     931e78bf-bb0d-4f47-9dfc-f550dcfa0763 2024-06-13 18:48:11
# ...                                    ...                 ...
# 1603  56358ba0-3fad-43f7-9bf6-a7c86f2aec00 2024-06-13 18:48:09
# 1604  1131d277-a364-4216-aa3b-51079183aab5 2024-06-23 14:23:14
# 1605  3fa4f5f1-e260-43f5-86cc-c876303235cf 2024-06-13 18:48:12
# 1606  19742db3-9121-4a6f-93dc-50cc051af77e 2024-06-23 13:38:26
# 1607  1123257d-8bc0-4192-84fc-1bfb71d57d82 2024-06-13 18:48:08
#
#               updated_at              deleted_at
# 0    2024-06-13 18:48:11                     NaT
# 1    2024-06-13 18:48:15                     NaT
# 2    2024-06-23 14:11:25 2024-06-23 14:11:25.351
# 3    2024-06-13 18:48:14                     NaT
# 4    2024-06-20 09:55:01 2024-06-20 09:55:01.457
# ...                  ...                     ...
# 1603 2024-06-13 18:48:09                     NaT
# 1604 2024-06-23 14:23:14                     NaT
# 1605 2024-06-13 18:48:12                     NaT
# 1606 2024-06-23 13:39:12 2024-06-23 13:39:12.825
# 1607 2024-06-13 18:48:08                     NaT
#
# [1608 rows x 6 columns]

# %% [markdown]
# #### 4.7 Tampilkan Dataframe facilities

# %%
df_facilities = dataframes['facilities']
df_facilities
# Out:
#                                       id              name  \
# 0   1123257d-8bc0-4192-84fc-1bfb71d57d82     Tempat Sampah
# 1   1131d277-a364-4216-aa3b-51079183aab5     Rumah Difabel
# 2   19742db3-9121-4a6f-93dc-50cc051af77e    Toko Oleh-oleh
# 3   26668988-d77c-41b9-84ee-b954df8d7abf  Wahana Permainan
# 4   3fa4f5f1-e260-43f5-86cc-c876303235cf            Toilet
# 5   40c09801-cbe2-4451-b781-7c843148d647     Ramah Difabel
# 6   56358ba0-3fad-43f7-9bf6-a7c86f2aec00   Pusat Informasi
# 7   931e78bf-bb0d-4f47-9dfc-f550dcfa0763      Area Makanan
# 8   a5990fd0-6d85-4273-bb17-d912b688469c       Area Parkir
# 9   ca8f1e7e-887d-4eac-b93e-d5a4c098a04d     Tempat Ibadah
# 10  e9ff877e-a324-441e-8175-53af5f0dc191        Penginapan
#
#                                                   url          created_at  \
# 0   https://storage.googleapis.com/provinces_url/f... 2024-06-13 18:48:05
# 1   https://storage.googleapis.com/provinces_url/f... 2024-06-16 15:02:37
# 2   https://storage.googleapis.com/provinces_url/f... 2024-06-13 18:48:05
# 3   https://storage.googleapis.com/provinces_url/f... 2024-06-13 18:48:05
# 4   https://storage.googleapis.com/provinces_url/f... 2024-06-13 18:48:05
# 5   https://storage.googleapis.com/provinces_url/f... 2024-06-13 18:48:05
# 6   https://storage.googleapis.com/provinces_url/f... 2024-06-13 18:48:05
# 7   https://storage.googleapis.com/provinces_url/f... 2024-06-13 18:48:05
# 8   https://storage.googleapis.com/provinces_url/f... 2024-06-13 18:48:05
# 9   https://storage.googleapis.com/provinces_url/f... 2024-06-13 18:48:05
# 10  https://storage.googleapis.com/provinces_url/f... 2024-06-13 18:48:05
#
#             updated_at deleted_at
# 0  2024-06-13 18:48:05       None
# 1  2024-06-16 15:02:37       None
# 2  2024-06-13 18:48:05       None
# 3  2024-06-13 18:48:05       None
# 4  2024-06-13 18:48:05       None
# 5  2024-06-16 10:47:08       None
# 6  2024-06-13 18:48:05       None
# 7  2024-06-13 18:48:05       None
# 8  2024-06-13 18:48:05       None
# 9  2024-06-13 18:48:05       None
# 10 2024-06-13 18:48:05       None

# %% [markdown]
# #### 4.8 Tampilkan Dataframe destination_addresses

# %%
df_destination_addresses = dataframes['destination_addresses']
df_destination_addresses
# Out:
#                                        id  \
# 0    011d2cae-f2bd-425f-8bce-8af97b9208c1
# 1    012d8602-cca7-47ec-9c60-b4e3b6ce9e63
# 2    02110a57-a844-4c11-af2e-5df5fe6cd36c
# 3    028a7c9f-1649-4109-8416-aeab6ecf3b87
# 4    029b0550-2532-40ed-ae5f-80a6f0eddc3f
# ..                                    ...
# 427  fcf1ce25-952f-4f47-b6bc-a1c9ae7701f8
# 428  fd7a687b-f7fc-482f-80ab-831b9306ab56
# 429  ffc60529-fe1f-498b-92e3-a0e274055aeb
# 430  ffdb9337-4783-4db4-875d-dcf0f17392fc
# 431  ffffb02d-f952-486a-837a-80c70cb184a1
#
#                            destination_id province_id city_id subdistrict_id  \
# 0    ce7170a6-7f38-42b8-8165-90303f381aee          64    6402         640206
# 1    be5a64df-c174-4829-b9c5-a01c82f78c15          34    3404         331001
# 2    8aae7ff2-580b-42fe-958a-2b928ee54615          73    7302         320522
# 3    de220174-9f2d-42bf-b821-c02a510d215c          81    8101         110315
# 4    e3e7445e-6aec-4c84-8dea-ecd11476cb49          34    3471         347110
# ..                                    ...         ...     ...            ...
# 427  c752381e-bf5e-48c7-b8f2-27a07959bee8          34    3471         347109
# 428  e7e9e5a3-b19f-41f7-b4f6-6b27f444303e          71    7171         717109
# 429  f31d786b-61a9-447b-8827-07b384c03689          17    1701         177106
# 430  35a8a9e5-f192-4228-94e6-93e58b94987b          74    7471         747104
# 431  b088cb7a-daab-4157-8299-4d74e34ff51d          16    1672         167201
#
#                                            street_name postal_code  \
# 0                                 Jl. Diponegoro No.26       75513
# 1    Jl. Raya Solo - Yogyakarta No. 16, Kranggan, B...       55571
# 2                                        Jl. Tanah Toa       92574
# 3                                      Jl. Istana Mini       97586
# 4                                      Jl. Margo Mulyo       55122
# ..                                                 ...         ...
# 427             Jl. Rotowijayan Blok No. 1, Panembahan       55131
# 428                       Jl. Ring Road Trans Sulawesi       95885
# 429                                     Jl. Pariwisata       38116
# 430                         Jl. Kebun Raya Nanga Nanga       93237
# 431                                  Jl. Dempio Makmur       31581
#
#              created_at          updated_at deleted_at
# 0   2024-06-11 08:28:20 2024-06-11 08:28:20        NaT
# 1   2024-06-11 08:28:27 2024-06-11 08:28:27        NaT
# 2   2024-06-11 08:28:28 2024-06-11 08:28:28        NaT
# 3   2024-06-11 08:28:30 2024-06-11 08:28:30        NaT
# 4   2024-06-11 08:28:27 2024-06-11 08:28:27        NaT
# ..                  ...                 ...        ...
# 427 2024-06-11 08:28:27 2024-06-11 08:28:27        NaT
# 428 2024-06-11 08:28:21 2024-06-11 08:28:21        NaT
# 429 2024-06-11 08:28:25 2024-06-11 08:28:25        NaT
# 430 2024-06-11 08:28:29 2024-06-11 08:28:29        NaT
# 431 2024-06-11 08:28:23 2024-06-11 08:28:23        NaT
#
# [432 rows x 10 columns]

# %% [markdown]
# #### 4.9 Tampilkan Dataframe provinces

# %%
df_provinces = dataframes['provinces']
df_provinces
# Out:
#     id                       name  \
# 0   11   Nanggroe Aceh Darussalam
# 1   12             Sumatera Utara
# 2   13             Sumatera Barat
# 3   14                       Riau
# 4   15                      Jambi
# 5   16           Sumatera Selatan
# 6   17                   Bengkulu
# 7   18                    Lampung
# 8   19  Kepulauan Bangka Belitung
# 9   21             Kepulauan Riau
# 10  31                DKI Jakarta
# 11  32                 Jawa Barat
# 12  33                Jawa Tengah
# 13  34              DI Yogyakarta
# 14  35                 Jawa Timur
# 15  36                     Banten
# 16  51                       Bali
# 17  52        Nusa Tenggara Barat
# 18  53        Nusa Tenggara Timur
# 19  61           Kalimantan Barat
# 20  62          Kalimantan Tengah
# 21  63         Kalimantan Selatan
# 22  64           Kalimantan Timur
# 23  65           Kalimantan Utara
# 24  71             Sulawesi Utara
# 25  72            Sulawesi Tengah
# 26  73           Sulawesi Selatan
# 27  74          Sulawesi Tenggara
# 28  75                  Gorontalo
# 29  76             Sulawesi Barat
# 30  81                     Maluku
# 31  82               Maluku Utara
# 32  91                      Papua
# 33  92                Papua Barat
# 34  93              Papua Selatan
# 35  94               Papua Tengah
# 36  95           Papua Pegunungan
# 37  96           Papua Barat Daya
#
#                                                   url          created_at  \
# 0   https://storage.googleapis.com/provinces_url/a... 2024-06-23 08:52:09
# 1   https://storage.googleapis.com/provinces_url/s... 2024-06-23 08:52:09
# 2   https://storage.googleapis.com/provinces_url/s... 2024-06-23 08:52:09
# 3   https://storage.googleapis.com/provinces_url/r... 2024-06-23 08:52:09
# 4   https://storage.googleapis.com/provinces_url/j... 2024-06-23 08:52:09
# 5   https://storage.googleapis.com/provinces_url/s... 2024-06-23 08:52:09
# 6   https://storage.googleapis.com/provinces_url/b... 2024-06-23 08:52:09
# 7   https://storage.googleapis.com/provinces_url/l... 2024-06-23 08:52:09
# 8   https://storage.googleapis.com/provinces_url/b... 2024-06-23 08:52:09
# 9   https://storage.googleapis.com/provinces_url/k... 2024-06-23 08:52:09
# 10  https://storage.googleapis.com/provinces_url/j... 2024-06-23 08:52:09
# 11  https://storage.googleapis.com/provinces_url/j... 2024-06-23 08:52:09
# 12  https://storage.googleapis.com/provinces_url/j... 2024-06-23 08:52:09
# 13  https://storage.googleapis.com/provinces_url/d... 2024-06-23 08:52:09
# 14  https://storage.googleapis.com/provinces_url/j... 2024-06-23 08:52:09
# 15  https://storage.googleapis.com/provinces_url/b... 2024-06-23 08:52:09
# 16  https://storage.googleapis.com/provinces_url/b... 2024-06-23 08:52:09
# 17  https://storage.googleapis.com/provinces_url/n... 2024-06-23 08:52:09
# 18  https://storage.googleapis.com/provinces_url/n... 2024-06-23 08:52:09
# 19  https://storage.googleapis.com/provinces_url/k... 2024-06-23 08:52:09
# 20  https://storage.googleapis.com/provinces_url/k... 2024-06-23 08:52:09
# 21  https://storage.googleapis.com/provinces_url/k... 2024-06-23 08:52:09
# 22  https://storage.googleapis.com/provinces_url/k... 2024-06-23 08:52:09
# 23  https://storage.googleapis.com/provinces_url/k... 2024-06-23 08:52:09
# 24  https://storage.googleapis.com/provinces_url/s... 2024-06-23 08:52:09
# 25  https://storage.googleapis.com/provinces_url/s... 2024-06-23 08:52:09
# 26  https://storage.googleapis.com/provinces_url/s... 2024-06-23 08:52:09
# 27  https://storage.googleapis.com/provinces_url/s... 2024-06-23 08:52:09
# 28  https://storage.googleapis.com/provinces_url/g... 2024-06-23 08:52:09
# 29  https://storage.googleapis.com/provinces_url/s... 2024-06-23 08:52:09
# 30  https://storage.googleapis.com/provinces_url/m... 2024-06-23 08:52:09
# 31  https://storage.googleapis.com/provinces_url/m... 2024-06-23 08:52:09
# 32  https://storage.googleapis.com/provinces_url/p... 2024-06-23 08:52:09
# 33  https://storage.googleapis.com/provinces_url/p... 2024-06-23 08:52:09
# 34  https://storage.googleapis.com/provinces_url/p... 2024-06-23 08:52:09
# 35  https://storage.googleapis.com/provinces_url/p... 2024-06-23 08:52:09
# 36  https://storage.googleapis.com/provinces_url/p... 2024-06-23 08:52:09
# 37  https://storage.googleapis.com/provinces_url/p... 2024-06-23 08:52:09
#
#             updated_at deleted_at
# 0  2024-06-23 08:52:09       None
# 1  2024-06-23 08:52:09       None
# 2  2024-06-23 08:52:09       None
# 3  2024-06-23 08:52:09       None
# 4  2024-06-23 08:52:09       None
# 5  2024-06-23 08:52:09       None
# 6  2024-06-23 08:52:09       None
# 7  2024-06-23 08:52:09       None
# 8  2024-06-23 08:52:09       None
# 9  2024-06-23 08:52:09       None
# 10 2024-06-23 08:52:09       None
# 11 2024-06-23 08:52:09       None
# 12 2024-06-23 08:52:09       None
# 13 2024-06-23 08:52:09       None
# 14 2024-06-23 08:52:09       None
# 15 2024-06-23 08:52:09       None
# 16 2024-06-23 08:52:09       None
# 17 2024-06-23 08:52:09       None
# 18 2024-06-23 08:52:09       None
# 19 2024-06-23 08:52:09       None
# 20 2024-06-23 08:52:09       None
# 21 2024-06-23 08:52:09       None
# 22 2024-06-23 08:52:09       None
# 23 2024-06-23 08:52:09       None
# 24 2024-06-23 08:52:09       None
# 25 2024-06-23 08:52:09       None
# 26 2024-06-23 08:52:09       None
# 27 2024-06-23 08:52:09       None
# 28 2024-06-23 08:52:09       None
# 29 2024-06-23 08:52:09       None
# 30 2024-06-23 08:52:09       None
# 31 2024-06-23 08:52:09       None
# 32 2024-06-23 08:52:09       None
# 33 2024-06-23 08:52:09       None
# 34 2024-06-23 08:52:09       None
# 35 2024-06-23 08:52:09       None
# 36 2024-06-23 08:52:09       None
# 37 2024-06-23 08:52:09       None

# %% [markdown]
# #### 4.10 Tampilkan Dataframe cities

# %%
df_cities = dataframes['cities']
df_cities
# Out:
#        id province_id                   name          created_at  \
# 0    1101          11      KAB. ACEH SELATAN 2024-06-11 08:27:47
# 1    1102          11     KAB. ACEH TENGGARA 2024-06-11 08:27:47
# 2    1103          11        KAB. ACEH TIMUR 2024-06-11 08:27:47
# 3    1104          11       KAB. ACEH TENGAH 2024-06-11 08:27:47
# 4    1105          11        KAB. ACEH BARAT 2024-06-11 08:27:47
# ..    ...         ...                    ...                 ...
# 509  9504          95          KAB. TOLIKARA 2024-06-11 08:27:49
# 510  9505          95  KAB. MAMBERAMO TENGAH 2024-06-11 08:27:49
# 511  9506          95            KAB. YALIMO 2024-06-11 08:27:49
# 512  9507          95        KAB. LANNY JAYA 2024-06-11 08:27:49
# 513  9508          95             KAB. NDUGA 2024-06-11 08:27:49
#
#              updated_at deleted_at
# 0   2024-06-11 08:27:47       None
# 1   2024-06-11 08:27:47       None
# 2   2024-06-11 08:27:47       None
# 3   2024-06-11 08:27:47       None
# 4   2024-06-11 08:27:47       None
# ..                  ...        ...
# 509 2024-06-11 08:27:49       None
# 510 2024-06-11 08:27:49       None
# 511 2024-06-11 08:27:49       None
# 512 2024-06-11 08:27:49       None
# 513 2024-06-11 08:27:49       None
#
# [514 rows x 6 columns]

# %% [markdown]
# #### 4.11 Tampilkan Dataframe subdistricts

# %%
df_subdistricts = dataframes['subdistricts']
df_subdistricts
# Out:
#           id city_id               name          created_at  \
# 0     110101    1101           Bakongan 2024-06-11 08:27:49
# 1     110102    1101        Kluet Utara 2024-06-11 08:27:49
# 2     110103    1101      Kluet Selatan 2024-06-11 08:27:49
# 3     110104    1101        Labuhanhaji 2024-06-11 08:27:49
# 4     110105    1101             Meukek 2024-06-11 08:27:49
# ...      ...     ...                ...                 ...
# 7283  950839    9304            Yakapis 2024-06-11 08:28:17
# 7284  950840    9171    Distrik Ebungfa 2024-06-11 08:28:14
# 7285  950841    9171      Distrik Waibu 2024-06-11 08:28:14
# 7286  950842    9501           Palebaga 2024-06-11 08:28:14
# 7287  950843    9202  Distrik Manokwari 2024-06-11 08:28:14
#
#               updated_at deleted_at
# 0    2024-06-11 08:27:49       None
# 1    2024-06-11 08:27:49       None
# 2    2024-06-11 08:27:49       None
# 3    2024-06-11 08:27:49       None
# 4    2024-06-11 08:27:49       None
# ...                  ...        ...
# 7283 2024-06-11 08:28:17       None
# 7284 2024-06-11 08:28:14       None
# 7285 2024-06-11 08:28:14       None
# 7286 2024-06-11 08:28:14       None
# 7287 2024-06-11 08:28:14       None
#
# [7288 rows x 6 columns]

# %% [markdown]
# #### 4.12 Tampilkan Dataframe destination_media

# %%
df_destination_media = dataframes['destination_media']
df_destination_media
# Out:
#                                         id  \
# 0     00288a35-9e58-4fb5-8e1d-894c3e0ca43a
# 1     00309f32-5614-4731-8614-ac287d480a11
# 2     0046a99f-16a2-4086-b2df-b3d79048223c
# 3     005548a8-a773-4215-8144-b6feeb0eba4d
# 4     005f762b-2ff7-4f2f-8f3b-06d1a9ee449a
# ...                                    ...
# 2062  ffa9ff93-32dd-413d-88fb-9f945f800f68
# 2063  ffbc6ba5-8902-4625-9851-403a7dae707b
# 2064  ffccc3c8-43d5-4244-9fff-533e3abdbf76
# 2065  ffed9c82-d094-4e7d-9595-53fc66831e53
# 2066  fff78127-312b-4942-b29d-7f56b5666b06
#
#                             destination_id  \
# 0     ee6c0ad0-fd22-46c2-96f2-178899751cd5
# 1     71a5ecfb-ffad-4300-9ef9-8fed51baf2a3
# 2     73697664-ba03-4de1-ad47-13fa4f95abcd
# 3     1c8539f7-a4c1-42b4-8e8e-4be2a16c1341
# 4     5ee3507b-78fa-405a-a6b3-c46d7a818a43
# ...                                    ...
# 2062  11ba8d8d-f4c1-4916-870f-30e3ce0dc050
# 2063  c04b5eb5-53cc-4692-9138-3647f598f8b8
# 2064  d2ef9e75-3443-4d7c-9188-04ce25e8d3fa
# 2065  ee6c0ad0-fd22-46c2-96f2-178899751cd5
# 2066  f31d786b-61a9-447b-8827-07b384c03689
#
#                                                     url   type  \
# 0                                             video.jpg  video
# 1     https://indonesia.go.id/assets/upload/headline...  image
# 2     https://storage.googleapis.com/provinces_url/v...  video
# 3     https://storage.googleapis.com/provinces_url/v...  video
# 4     https://asset-2.tstatic.net/travel/foto/bank/i...  image
# ...                                                 ...    ...
# 2062  https://assets.promediateknologi.id/crop/0x0:0...  image
# 2063  https://gerbanglombok.co.id/wp-content/uploads...  image
# 2064  https://www.batiqa.com/upload/news/z/pekanbaru...  image
# 2065  https://as2.ftcdn.net/v2/jpg/01/43/61/77/1000_...  image
# 2066  https://storage.googleapis.com/provinces_url/v...  video
#
#                                                   title          created_at  \
# 0                             We Are Going On Bullrun 3 2024-06-11 08:28:29
# 1     Danau Limboto, destinasi yang tenang dan indah... 2024-06-20 15:12:08
# 2         Mengagumi Arsitektur Unik Gedung Sate Bandung 2024-06-11 08:28:33
# 3     Pesona Rumah Etnik Papua yang Memikat: Arsitek... 2024-06-11 08:28:32
# 4     Serunya Liburan Keluarga di Taman Kyai Langgen... 2024-06-11 08:28:34
# ...                                                 ...                 ...
# 2062  Keindahan Pulau Kakara yang Mempesona: Pulau K... 2024-06-11 08:28:30
# 2063  Rasakan keajaiban alam Lombok dengan air terju... 2024-06-11 08:28:17
# 2064  Menjelajahi Kemegahan Istana Siak Sri Indrapur... 2024-06-11 08:28:24
# 2065  Pesona Desa Wisata Sawai: Desa Wisata dengan K... 2024-06-11 08:28:29
# 2066  Pantai Panjang: Destinasi Wisata Pantai Terind... 2024-06-11 08:28:25
#
#               updated_at              deleted_at
# 0    2024-06-17 15:58:01 2024-06-17 15:58:01.905
# 1    2024-06-20 15:12:08                     NaT
# 2    2024-06-17 15:57:49 2024-06-17 15:57:49.221
# 3    2024-06-19 04:59:51 2024-06-19 04:59:51.279
# 4    2024-06-11 08:28:34                     NaT
# ...                  ...                     ...
# 2062 2024-06-11 08:28:30                     NaT
# 2063 2024-06-11 08:28:17                     NaT
# 2064 2024-06-11 08:28:24                     NaT
# 2065 2024-06-23 14:09:54 2024-06-23 14:09:54.362
# 2066 2024-06-11 08:28:25                     NaT
#
# [2067 rows x 8 columns]

# %% [markdown]
# #### 4.13 Tampilkan Dataframe admins

# %%
df_admins = dataframes['admins']
df_admins
# Out:
#                                        id    username  \
# 0    009a0156-0643-4da4-a749-43743ef84c11    adminke9
# 1    01ce89ca-2ee1-43e3-aef2-85293573bf2d    adminke8
# 2    01e14a5a-192b-47ba-9811-b6b998a76f0c    adminke8
# 3    0222c650-a4b5-4064-86d6-e637ab0bc555   testadmin
# 4    0490e6e3-2cad-4483-9669-6eb8c3cdb3b6    username
# ..                                    ...         ...
# 229  f963de2c-026e-4182-9f48-9091964e17b1   testadmin
# 230  fb970537-67ac-4d81-8cba-473b97e9fbdf   Leviathan
# 231  fd94aa1a-5e8e-44e2-8b2c-c79f9fa03000  adminke100
# 232  fe4a6c0a-0e4f-4cdb-aa47-6efd91b0448e   testadmin
# 233  fe9a4a03-3f5a-492e-936d-01216c6f4e91    adminke8
#
#                                               password  \
# 0    $2a$10$KlaOAI8Wj8ayK160YZ8aS.lK3rxGvzeUSeYfVZp...
# 1    $2a$10$GwRtvI55ejEpvea0sahqUuOqvS75UBd5wGJfPwD...
# 2    $2a$10$lupuwi9OEzj6adGHGFgyzuE/x3EujgvnW2S5GF....
# 3    $2a$10$hkAjaTJqNjxUDQ8/5DSnCuviT.qzDN3vjazXys/...
# 4    $2a$10$GguFg4Rxqa8LELhfNFi70ekCQbc8qVkOSApftq2...
# ..                                                 ...
# 229  $2a$10$JNU7StlZIDUrpZHxTB2orO17O4y7JF1DEKHhCXH...
# 230  $2a$10$sJ3Nz7a8FtA2YyWpOIcSkuDykAjQiGKHzaA6H93...
# 231  $2a$10$ttzIbOhLocFqIUTDJFWRiuZGtqfCOI0x5WUxt9P...
# 232  $2a$10$gswiDkJAAbqgh3yw2uMkmO08BJzhsXzF0q4Ky4L...
# 233  $2a$10$6dXt6Tspsm/vjYK8LWcx5u.qK6X.qVPvL0lhGCZ...
#
#                                      profile_image_url   role refresh_token  \
# 0                                                 None  admin
# 1                                                 None  admin
# 2                                                 None  admin
# 3                                                 None  admin
# 4                                                 None  admin
# ..                                                 ...    ...           ...
# 229                                               None  admin
# 230  https://res.cloudinary.com/alta-minpro/image/u...  admin
# 231                                               None  admin
# 232                                               None  admin
# 233                                               None  admin
#
#              created_at          updated_at              deleted_at  \
# 0   2024-06-21 07:48:44 2024-06-21 07:50:04 2024-06-21 07:50:03.572
# 1   2024-06-14 14:18:37 2024-06-14 14:18:41 2024-06-14 14:18:40.828
# 2   2024-06-21 07:47:56 2024-06-21 08:17:21 2024-06-21 08:17:20.786
# 3   2024-06-17 11:39:28 2024-06-17 11:39:36 2024-06-17 11:39:36.237
# 4   2024-06-08 10:28:28 2024-06-11 14:33:16 2024-06-11 14:33:15.525
# ..                  ...                 ...                     ...
# 229 2024-06-15 12:43:47 2024-06-17 06:10:42 2024-06-17 06:10:41.899
# 230 2024-06-23 12:50:38 2024-06-23 12:50:38                     NaT
# 231 2024-06-19 13:24:16 2024-06-19 13:30:02 2024-06-19 13:30:01.969
# 232 2024-06-19 06:05:44 2024-06-19 06:07:16 2024-06-19 06:07:15.901
# 233 2024-06-19 13:36:33 2024-06-19 13:36:40 2024-06-19 13:36:39.621
#
#       delete_milli
# 0    1718956203569
# 1    1718374720826
# 2    1718957840784
# 3    1718624376235
# 4    1718116395523
# ..             ...
# 229  1718604641896
# 230              0
# 231  1718803801967
# 232  1718777235899
# 233  1718804199619
#
# [234 rows x 10 columns]

# %% [markdown]
# ### 5. Transformation

# %% [markdown]
# #### 5.1 Merged df_destination_facilities dan df_facilities

# %%
# Menggabungkan DataFrame
df_merged_facilities = pd.merge(df_destination_facilities, df_facilities, left_on='facility_id', right_on='id')

# Memilih kolom yang diinginkan dari df_facilities
df_dim_facilities = df_merged_facilities[['facility_id', 'name', 'url']].drop_duplicates()
df_dim_facilities.rename(columns={'facility_id': 'id'}, inplace=True)

# Mengurutkan index kembali
df_dim_facilities.reset_index(drop=True, inplace=True)

# %% [markdown]
# ##### 5.1.1 Dim Facilities

# %%
# Menampilkan DataFrame hasil
df_dim_facilities
# Out:
#                                       id              name  \
# 0   19742db3-9121-4a6f-93dc-50cc051af77e    Toko Oleh-oleh
# 1   a5990fd0-6d85-4273-bb17-d912b688469c       Area Parkir
# 2   56358ba0-3fad-43f7-9bf6-a7c86f2aec00   Pusat Informasi
# 3   931e78bf-bb0d-4f47-9dfc-f550dcfa0763      Area Makanan
# 4   1123257d-8bc0-4192-84fc-1bfb71d57d82     Tempat Sampah
# 5   3fa4f5f1-e260-43f5-86cc-c876303235cf            Toilet
# 6   ca8f1e7e-887d-4eac-b93e-d5a4c098a04d     Tempat Ibadah
# 7   e9ff877e-a324-441e-8175-53af5f0dc191        Penginapan
# 8   1131d277-a364-4216-aa3b-51079183aab5     Rumah Difabel
# 9   26668988-d77c-41b9-84ee-b954df8d7abf  Wahana Permainan
# 10  40c09801-cbe2-4451-b781-7c843148d647     Ramah Difabel
#
#                                                   url
# 0   https://storage.googleapis.com/provinces_url/f...
# 1   https://storage.googleapis.com/provinces_url/f...
# 2   https://storage.googleapis.com/provinces_url/f...
# 3   https://storage.googleapis.com/provinces_url/f...
# 4   https://storage.googleapis.com/provinces_url/f...
# 5   https://storage.googleapis.com/provinces_url/f...
# 6   https://storage.googleapis.com/provinces_url/f...
# 7   https://storage.googleapis.com/provinces_url/f...
# 8   https://storage.googleapis.com/provinces_url/f...
# 9   https://storage.googleapis.com/provinces_url/f...
# 10  https://storage.googleapis.com/provinces_url/f...

# %% [markdown]
# #### 5.2 Merged df_destination_addresses dengan df_provinces, df_cities, df_subdistricts

# %%
# Gabungkan DataFrame
df_merged_address = pd.merge(df_destination_addresses, df_provinces, left_on='province_id', right_on='id', suffixes=('_dest', '_prov'))
df_merged_address = pd.merge(df_merged_address, df_cities, left_on='city_id', right_on='id', suffixes=('_prov', '_city'))
df_merged_address = pd.merge(df_merged_address, df_subdistricts, left_on='subdistrict_id', right_on='id', suffixes=('_city', '_subd'))

# Pilih kolom yang diinginkan
df_dim_address = df_merged_address[['id_dest', 'name_prov', 'name_city', 'name', 'street_name', 'postal_code']]

# Ubah nama kolom
df_dim_address.columns = ['id', 'provinces', 'cities', 'subdistricts', 'street_name', 'postal_code']

# %% [markdown]
# ##### 5.2.1 Dim Address

# %%
# Tampilkan DataFrame hasil
df_dim_address
# Out:
#                                        id         provinces  \
# 0    011d2cae-f2bd-425f-8bce-8af97b9208c1  Kalimantan Timur
# 1    e3d168e4-f92a-449f-af5c-a7af23305a69  Kalimantan Timur
# 2    cec8c58b-4918-48d3-8897-bd01593f46b4  Kalimantan Timur
# 3    25244f03-3a67-4da1-9d81-c7a7150e2109  Kalimantan Timur
# 4    5f160160-402b-4956-8667-eadbdaafc370  Kalimantan Timur
# ..                                    ...               ...
# 427  97f567c6-e52f-4d19-9682-41ef5caf2d4a    Sulawesi Utara
# 428  e8263a09-b790-4174-a185-c84d8cf3585e    Sulawesi Utara
# 429  a1301280-657c-4300-8941-c71abecea77b    Sulawesi Utara
# 430  cffb9944-aa89-4819-ab3c-8c3da4d24f13    Sulawesi Utara
# 431  fd7a687b-f7fc-482f-80ab-831b9306ab56    Sulawesi Utara
#
#                      cities     subdistricts                   street_name  \
# 0    KAB. KUTAI KARTANEGARA       Tenggarong          Jl. Diponegoro No.26
# 1    KAB. KUTAI KARTANEGARA       Tenggarong                     Jl. Panji
# 2    KAB. KUTAI KARTANEGARA          Samboja             Jl. Bukit Merdeka
# 3                KAB. BERAU       Batu Putih     Jl. Desa Tulung Ni'Lenggo
# 4                KAB. BERAU      Biduk-Biduk            Jl. Labuan Kelambu
# ..                      ...              ...                           ...
# 427           KAB. MINAHASA    Tondano Barat          Jl. Langowan-Tondano
# 428           KAB. MINAHASA         Pineleng           Jl. Menuju ke Salib
# 429            KOTA TOMOHON  Tomohon Selatan                 Jl. Lahendong
# 430            KOTA TOMOHON  Tomohon Selatan                   Jl. Pinaras
# 431             KOTA MANADO       Malalayang  Jl. Ring Road Trans Sulawesi
#
#     postal_code
# 0         75513
# 1         75513
# 2         75271
# 3         77372
# 4         77373
# ..          ...
# 427       95617
# 428       95661
# 429       95435
# 430       95434
# 431       95885
#
# [432 rows x 6 columns]

# %% [markdown]
# #### 5.3 Drop Column di df_destinations (Dim Destinations)

# %%
# Menghapus kolom-kolom yang tidak diinginkan
columns_to_drop = ['category_id', 'created_at', 'updated_at', 'deleted_at']
df_dim_destinations = df_destinations.drop(columns=columns_to_drop)

# Tampilkan hasil
df_dim_destinations
# Out:
#                                        id                         name  \
# 0    00319825-e81b-4a93-bf9a-eef836ccf6ce  Keraton Kasunanan Surakarta
# 1    005e32da-f5fb-405c-9772-f6424c011fac         Desa Wisata Kasongan
# 2    01b8da3a-3987-4976-9ae7-46d6b8eacee5          Saung Angklung Udjo
# 3    01ccaac9-97fe-42e1-8034-bc0c02471692    Museum Etnografi Sendawar
# 4    02834099-7ce7-44b9-8b27-e4db38f062bd                Danau Limboto
# ..                                    ...                          ...
# 427  fbee819e-2b7b-44fe-8d5a-74dd345cea0e                  Danau Tahai
# 428  fc780065-0848-467b-9625-9c24ecd2e9c2                  Pantai Maaf
# 429  fde8748a-2ec0-4211-89e5-12f3d63db81b          Piaynemo Raja Ampat
# 430  fe1ebfe5-365f-4893-aa36-91e380bb2011           Wisata Pantai Gedo
# 431  ff779270-ee68-46cc-929c-cdd67d328772                 Danau Emfote
#
#                                            description open_time close_time  \
# 0    Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 1    Desa yang terkenal dengan kerajinan gerabah da...      8:00      17:00
# 2    Saung Angklung Udjo adalah pusat Seni dan Buda...      8:00      17:00
# 3    Museum Etnografi Sendawar merupakan museum per...      9:00      18:00
# 4    Danau ini terletak di Kecamatan Limboto, tepat...      0:00      23:59
# ..                                                 ...       ...        ...
# 427  Di kawasan objek wisata Danau Tahai ini terdap...      0:00      23:59
# 428  Pantai Maaf menawarkan perairan yang damai den...      6:00      18:00
# 429  Piaynemo adalah salah satu ikon wisata di Raja...     10:00      17:00
# 430  Wisata Pantai Gedo adalah destinasi pantai ind...      6:00      18:00
# 431  Danau Emfote adalah salah satu destinasi alam ...      0:00      23:59
#
#      entry_price   longitude  latitude  visit_count
# 0        20000.0  110.827903 -7.577736          293
# 1            0.0  110.337978 -7.845291          243
# 2       120000.0  107.654684 -6.897701          203
# 3         5000.0  115.701909 -0.232651          134
# 4            0.0  123.007543  0.577025          219
# ..           ...         ...       ...          ...
# 427          0.0  113.783202 -2.027312          136
# 428      10000.0  135.496749 -3.360245          163
# 429     150000.0  130.270813 -0.564206          123
# 430      15000.0  135.546550 -3.309413          300
# 431      20000.0  140.539693 -2.660878          208
#
# [432 rows x 9 columns]

# %% [markdown]
# #### 5.4 Drop Column di df_categories (Dim Categories)

# %%
# Menghapus kolom-kolom yang tidak diinginkan
columns_to_drop = ['url', 'created_at', 'updated_at', 'deleted_at']
df_dim_categories = df_categories.drop(columns=columns_to_drop)

# Tampilkan DataFrame setelah penghapusan kolom
df_dim_categories
# Out:
#                                      id             name
# 0  eb77b590-b255-4ea1-b11a-d445a259ac61             Alam
# 1  eb77b590-b255-4ea1-b11a-d445a259ac62  Seni dan Budaya
# 2  eb77b590-b255-4ea1-b11a-d445a259ac63          Sejarah

# %% [markdown]
# #### 5.5 Drop Column di df_destination_media (Dim Medias)

# %%
# Menghapus kolom-kolom yang tidak diinginkan
columns_to_drop = ['destination_id', 'created_at', 'updated_at', 'deleted_at']
df_dim_medias = df_destination_media.drop(columns=columns_to_drop)

# Tampilkan DataFrame setelah penghapusan kolom
df_dim_medias
# Out:
#                                         id  \
# 0     00288a35-9e58-4fb5-8e1d-894c3e0ca43a
# 1     00309f32-5614-4731-8614-ac287d480a11
# 2     0046a99f-16a2-4086-b2df-b3d79048223c
# 3     005548a8-a773-4215-8144-b6feeb0eba4d
# 4     005f762b-2ff7-4f2f-8f3b-06d1a9ee449a
# ...                                    ...
# 2062  ffa9ff93-32dd-413d-88fb-9f945f800f68
# 2063  ffbc6ba5-8902-4625-9851-403a7dae707b
# 2064  ffccc3c8-43d5-4244-9fff-533e3abdbf76
# 2065  ffed9c82-d094-4e7d-9595-53fc66831e53
# 2066  fff78127-312b-4942-b29d-7f56b5666b06
#
#                                                     url   type  \
# 0                                             video.jpg  video
# 1     https://indonesia.go.id/assets/upload/headline...  image
# 2     https://storage.googleapis.com/provinces_url/v...  video
# 3     https://storage.googleapis.com/provinces_url/v...  video
# 4     https://asset-2.tstatic.net/travel/foto/bank/i...  image
# ...                                                 ...    ...
# 2062  https://assets.promediateknologi.id/crop/0x0:0...  image
# 2063  https://gerbanglombok.co.id/wp-content/uploads...  image
# 2064  https://www.batiqa.com/upload/news/z/pekanbaru...  image
# 2065  https://as2.ftcdn.net/v2/jpg/01/43/61/77/1000_...  image
# 2066  https://storage.googleapis.com/provinces_url/v...  video
#
#                                                   title
# 0                             We Are Going On Bullrun 3
# 1     Danau Limboto, destinasi yang tenang dan indah...
# 2         Mengagumi Arsitektur Unik Gedung Sate Bandung
# 3     Pesona Rumah Etnik Papua yang Memikat: Arsitek...
# 4     Serunya Liburan Keluarga di Taman Kyai Langgen...
# ...                                                 ...
# 2062  Keindahan Pulau Kakara yang Mempesona: Pulau K...
# 2063  Rasakan keajaiban alam Lombok dengan air terju...
# 2064  Menjelajahi Kemegahan Istana Siak Sri Indrapur...
# 2065  Pesona Desa Wisata Sawai: Desa Wisata dengan K...
# 2066  Pantai Panjang: Destinasi Wisata Pantai Terind...
#
# [2067 rows x 4 columns]

# %% [markdown]
# #### 5.6 Merged for Fact Table (destination_fact)

# %%
# Merge dataframes
merged_df = pd.merge(df_destinations, df_categories, left_on='category_id', right_on='id', suffixes=('_destinations', '_categories'))
merged_df = pd.merge(merged_df, df_destination_media, left_on='id_destinations', right_on='destination_id')
merged_df = pd.merge(merged_df, df_destination_facilities, left_on='id_destinations', right_on='destination_id', how='left')
merged_df = pd.merge(merged_df, df_destination_addresses, left_on='id_destinations', right_on='destination_id', how='left')

merged_df
# Out:
#                            id_destinations  \
# 0     00319825-e81b-4a93-bf9a-eef836ccf6ce
# 1     00319825-e81b-4a93-bf9a-eef836ccf6ce
# 2     00319825-e81b-4a93-bf9a-eef836ccf6ce
# 3     00319825-e81b-4a93-bf9a-eef836ccf6ce
# 4     00319825-e81b-4a93-bf9a-eef836ccf6ce
# ...                                    ...
# 8792  f968a9e0-2fae-4e1b-8ab4-edc5076b7b32
# 8793  f968a9e0-2fae-4e1b-8ab4-edc5076b7b32
# 8794  f968a9e0-2fae-4e1b-8ab4-edc5076b7b32
# 8795  f968a9e0-2fae-4e1b-8ab4-edc5076b7b32
# 8796  f968a9e0-2fae-4e1b-8ab4-edc5076b7b32
#
#                                category_id            name_destinations  \
# 0     eb77b590-b255-4ea1-b11a-d445a259ac62  Keraton Kasunanan Surakarta
# 1     eb77b590-b255-4ea1-b11a-d445a259ac62  Keraton Kasunanan Surakarta
# 2     eb77b590-b255-4ea1-b11a-d445a259ac62  Keraton Kasunanan Surakarta
# 3     eb77b590-b255-4ea1-b11a-d445a259ac62  Keraton Kasunanan Surakarta
# 4     eb77b590-b255-4ea1-b11a-d445a259ac62  Keraton Kasunanan Surakarta
# ...                                    ...                          ...
# 8792  eb77b590-b255-4ea1-b11a-d445a259ac63           Kota Lama Semarang
# 8793  eb77b590-b255-4ea1-b11a-d445a259ac63           Kota Lama Semarang
# 8794  eb77b590-b255-4ea1-b11a-d445a259ac63           Kota Lama Semarang
# 8795  eb77b590-b255-4ea1-b11a-d445a259ac63           Kota Lama Semarang
# 8796  eb77b590-b255-4ea1-b11a-d445a259ac63           Kota Lama Semarang
#
#                                             description open_time close_time  \
# 0     Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 1     Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 2     Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 3     Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 4     Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# ...                                                 ...       ...        ...
# 8792  Kota Lama Semarang adalah kawasan bersejarah d...      0:00      23:59
# 8793  Kota Lama Semarang adalah kawasan bersejarah d...      0:00      23:59
# 8794  Kota Lama Semarang adalah kawasan bersejarah d...      0:00      23:59
# 8795  Kota Lama Semarang adalah kawasan bersejarah d...      0:00      23:59
# 8796  Kota Lama Semarang adalah kawasan bersejarah d...      0:00      23:59
#
#       entry_price   longitude  latitude  visit_count  ...  \
# 0         20000.0  110.827903 -7.577736          293  ...
# 1         20000.0  110.827903 -7.577736          293  ...
# 2         20000.0  110.827903 -7.577736          293  ...
# 3         20000.0  110.827903 -7.577736          293  ...
# 4         20000.0  110.827903 -7.577736          293  ...
# ...           ...         ...       ...          ...  ...
# 8792          0.0  110.428436 -6.968299          248  ...
# 8793          0.0  110.428436 -6.968299          248  ...
# 8794          0.0  110.428436 -6.968299          248  ...
# 8795          0.0  110.428436 -6.968299          248  ...
# 8796          0.0  110.428436 -6.968299          248  ...
#
#                                         id  \
# 0     f9eefd7d-3af2-44c8-ae2e-135fefa6205c
# 1     f9eefd7d-3af2-44c8-ae2e-135fefa6205c
# 2     f9eefd7d-3af2-44c8-ae2e-135fefa6205c
# 3     f9eefd7d-3af2-44c8-ae2e-135fefa6205c
# 4     f9eefd7d-3af2-44c8-ae2e-135fefa6205c
# ...                                    ...
# 8792  a02b21cf-652f-4b31-8e01-295752b45df1
# 8793  a02b21cf-652f-4b31-8e01-295752b45df1
# 8794  a02b21cf-652f-4b31-8e01-295752b45df1
# 8795  a02b21cf-652f-4b31-8e01-295752b45df1
# 8796  a02b21cf-652f-4b31-8e01-295752b45df1
#
#                             destination_id province_id city_id subdistrict_id  \
# 0     00319825-e81b-4a93-bf9a-eef836ccf6ce          33    3372         337203
# 1     00319825-e81b-4a93-bf9a-eef836ccf6ce          33    3372         337203
# 2     00319825-e81b-4a93-bf9a-eef836ccf6ce          33    3372         337203
# 3     00319825-e81b-4a93-bf9a-eef836ccf6ce          33    3372         337203
# 4     00319825-e81b-4a93-bf9a-eef836ccf6ce          33    3372         337203
# ...                                    ...         ...     ...            ...
# 8792  f968a9e0-2fae-4e1b-8ab4-edc5076b7b32          33    3322         337402
# 8793  f968a9e0-2fae-4e1b-8ab4-edc5076b7b32          33    3322         337402
# 8794  f968a9e0-2fae-4e1b-8ab4-edc5076b7b32          33    3322         337402
# 8795  f968a9e0-2fae-4e1b-8ab4-edc5076b7b32          33    3322         337402
# 8796  f968a9e0-2fae-4e1b-8ab4-edc5076b7b32          33    3322         337402
#
#               street_name postal_code          created_at          updated_at  \
# 0         Jl. Kamandungan       57144 2024-06-11 08:28:33 2024-06-20 09:53:01
# 1         Jl. Kamandungan       57144 2024-06-11 08:28:33 2024-06-20 09:53:01
# 2         Jl. Kamandungan       57144 2024-06-11 08:28:33 2024-06-20 09:53:01
# 3         Jl. Kamandungan       57144 2024-06-11 08:28:33 2024-06-20 09:53:01
# 4         Jl. Kamandungan       57144 2024-06-11 08:28:33 2024-06-20 09:53:01
# ...                   ...         ...                 ...                 ...
# 8792  Jl. Letjen Suprapto       50174 2024-06-20 15:12:13 2024-06-20 15:12:13
# 8793  Jl. Letjen Suprapto       50174 2024-06-20 15:12:13 2024-06-20 15:12:13
# 8794  Jl. Letjen Suprapto       50174 2024-06-20 15:12:13 2024-06-20 15:12:13
# 8795  Jl. Letjen Suprapto       50174 2024-06-20 15:12:13 2024-06-20 15:12:13
# 8796  Jl. Letjen Suprapto       50174 2024-06-20 15:12:13 2024-06-20 15:12:13
#
#                   deleted_at
# 0    2024-06-20 09:53:01.794
# 1    2024-06-20 09:53:01.794
# 2    2024-06-20 09:53:01.794
# 3    2024-06-20 09:53:01.794
# 4    2024-06-20 09:53:01.794
# ...                      ...
# 8792                     NaT
# 8793                     NaT
# 8794                     NaT
# 8795                     NaT
# 8796                     NaT
#
# [8797 rows x 43 columns]

# %%
print(merged_df.columns)
# Out:
# Index(['id_destinations', 'category_id', 'name_destinations', 'description',
#        'open_time', 'close_time', 'entry_price', 'longitude', 'latitude',
#        'visit_count', 'created_at_destinations', 'updated_at_destinations',
#        'deleted_at_destinations', 'id_categories', 'name_categories', 'url_x',
#        'created_at_categories', 'updated_at_categories',
#        'deleted_at_categories', 'id_x', 'destination_id_x', 'url_y', 'type',
#        'title', 'created_at_x', 'updated_at_x', 'deleted_at_x', 'id_y',
#        'destination_id_y', 'facility_id', 'created_at_y', 'updated_at_y',
#        'deleted_at_y', 'id', 'destination_id', 'province_id', 'city_id',
#        'subdistrict_id', 'street_name', 'postal_code', 'created_at',
#        'updated_at', 'deleted_at'],
#       dtype='object')

# %% [markdown]
# #### 5.7 Merged for Fact Table

# %%
# Calculate additional columns
merged_df['total_content_video'] = (merged_df['type'] == 'video').astype(int)
merged_df['total_pendapatan'] = merged_df['entry_price'] * merged_df['visit_count']

# Select relevant columns for fact table
df_destination_fact = merged_df[['id_destinations', 'category_id', 'id_x', 'facility_id', 'id', 'total_content_video', 'total_pendapatan']]

# Rename columns
df_destination_fact.columns = ['destinations_id', 'categories_id', 'medias_id', 'facilities_id', 'address_id', 'total_content_video', 'total_pendapatan']

# Drop duplicates
df_destination_fact = df_destination_fact.drop_duplicates()

# Sort by destination_id
df_destination_fact = df_destination_fact.sort_values(by='destinations_id')

# Reset index to make it sequential
df_destination_fact = df_destination_fact.reset_index(drop=True)

# Preview the result
df_destination_fact
# Out:
#                            destinations_id  \
# 0     00319825-e81b-4a93-bf9a-eef836ccf6ce
# 1     00319825-e81b-4a93-bf9a-eef836ccf6ce
# 2     00319825-e81b-4a93-bf9a-eef836ccf6ce
# 3     00319825-e81b-4a93-bf9a-eef836ccf6ce
# 4     00319825-e81b-4a93-bf9a-eef836ccf6ce
# ...                                    ...
# 8792  ff779270-ee68-46cc-929c-cdd67d328772
# 8793  ff779270-ee68-46cc-929c-cdd67d328772
# 8794  ff779270-ee68-46cc-929c-cdd67d328772
# 8795  ff779270-ee68-46cc-929c-cdd67d328772
# 8796  ff779270-ee68-46cc-929c-cdd67d328772
#
#                              categories_id  \
# 0     eb77b590-b255-4ea1-b11a-d445a259ac62
# 1     eb77b590-b255-4ea1-b11a-d445a259ac62
# 2     eb77b590-b255-4ea1-b11a-d445a259ac62
# 3     eb77b590-b255-4ea1-b11a-d445a259ac62
# 4     eb77b590-b255-4ea1-b11a-d445a259ac62
# ...                                    ...
# 8792  eb77b590-b255-4ea1-b11a-d445a259ac61
# 8793  eb77b590-b255-4ea1-b11a-d445a259ac61
# 8794  eb77b590-b255-4ea1-b11a-d445a259ac61
# 8795  eb77b590-b255-4ea1-b11a-d445a259ac61
# 8796  eb77b590-b255-4ea1-b11a-d445a259ac61
#
#                                  medias_id  \
# 0     24ca36a8-d037-46a3-9d41-06f86e91aed7
# 1     f22dec50-95c5-42ea-ab87-e1a3e9b21811
# 2     f22dec50-95c5-42ea-ab87-e1a3e9b21811
# 3     f22dec50-95c5-42ea-ab87-e1a3e9b21811
# 4     af09a9a4-3cc2-4b36-a8d2-e2d06452db5d
# ...                                    ...
# 8792  dd3e286f-45e2-481d-90a8-3f6e92b86a43
# 8793  dd3e286f-45e2-481d-90a8-3f6e92b86a43
# 8794  fafb9b9b-4664-4efe-9fec-6be73612d22f
# 8795  35ecf9bf-a768-4f56-b954-971dd9b267d6
# 8796  35ecf9bf-a768-4f56-b954-971dd9b267d6
#
#                              facilities_id  \
# 0     56358ba0-3fad-43f7-9bf6-a7c86f2aec00
# 1     a5990fd0-6d85-4273-bb17-d912b688469c
# 2     19742db3-9121-4a6f-93dc-50cc051af77e
# 3     56358ba0-3fad-43f7-9bf6-a7c86f2aec00
# 4     a5990fd0-6d85-4273-bb17-d912b688469c
# ...                                    ...
# 8792  a5990fd0-6d85-4273-bb17-d912b688469c
# 8793  1123257d-8bc0-4192-84fc-1bfb71d57d82
# 8794  a5990fd0-6d85-4273-bb17-d912b688469c
# 8795  1123257d-8bc0-4192-84fc-1bfb71d57d82
# 8796  a5990fd0-6d85-4273-bb17-d912b688469c
#
#                                 address_id  total_content_video  \
# 0     f9eefd7d-3af2-44c8-ae2e-135fefa6205c                    1
# 1     f9eefd7d-3af2-44c8-ae2e-135fefa6205c                    0
# 2     f9eefd7d-3af2-44c8-ae2e-135fefa6205c                    0
# 3     f9eefd7d-3af2-44c8-ae2e-135fefa6205c                    0
# 4     f9eefd7d-3af2-44c8-ae2e-135fefa6205c                    0
# ...                                    ...                  ...
# 8792  a5d628a2-c2bf-48ba-aa55-e892bc7f3e4a                    0
# 8793  a5d628a2-c2bf-48ba-aa55-e892bc7f3e4a                    0
# 8794  a5d628a2-c2bf-48ba-aa55-e892bc7f3e4a                    1
# 8795  a5d628a2-c2bf-48ba-aa55-e892bc7f3e4a                    0
# 8796  a5d628a2-c2bf-48ba-aa55-e892bc7f3e4a                    0
#
#       total_pendapatan
# 0            5860000.0
# 1            5860000.0
# 2            5860000.0
# 3            5860000.0
# 4            5860000.0
# ...                ...
# 8792         4160000.0
# 8793         4160000.0
# 8794         4160000.0
# 8795         4160000.0
# 8796         4160000.0
#
# [8797 rows x 7 columns]

# %% [markdown]
# #### 5.8 Cek duplikasi dan Missing Value

# %%
# Cek missing values
missing_values = df_destination_fact.isnull().sum()
print("Jumlah Missing Values:\n", missing_values)

# Cek duplikasi data
duplicate_rows = df_destination_fact.duplicated().sum()
print("Jumlah Duplikasi Data:", duplicate_rows)
# Out:
# Jumlah Missing Values:
#  destinations_id        0
# categories_id          0
# medias_id              0
# facilities_id          0
# address_id             0
# total_content_video    0
# total_pendapatan       0
# dtype: int64
# Jumlah Duplikasi Data: 0

# %% [markdown]
# ### 6. Load to Big Query

# %% [markdown]
# #### 6.1 Konfigurasi ke Big Query

# %%
# Load environment variables from .env file
load_dotenv()

# Google Cloud configurations
project_id = os.getenv('GOOGLE_CLOUD_PROJECT_ID')
dataset_id = os.getenv('GOOGLE_CLOUD_DATASET_ID')
google_application_credentials = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')

# Set GOOGLE_APPLICATION_CREDENTIALS environment variable
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = google_application_credentials

# Load Google Cloud credentials
credentials = service_account.Credentials.from_service_account_file(google_application_credentials)

# %% [markdown]
# #### 6.2 Load dataframe to big query

# %%
# Dictionary to map DataFrame names to BigQuery table names
dataframes = {
    'dim_facilities': df_dim_facilities,
    'dim_address': df_dim_address,
    'dim_destinations': df_dim_destinations,
    'dim_categories': df_dim_categories,
    'dim_medias': df_dim_medias,
    'destination_fact': df_destination_fact,
    'admins': df_admins,
}

# Function to load DataFrame into BigQuery
def load_to_bq(df, table_name):
    table_id = f"{project_id}.{dataset_id}.{table_name}"
    to_gbq(df, table_id, project_id=project_id, if_exists='replace', credentials=credentials)

# Iterate over DataFrame dictionary and load each to BigQuery
for table_name, df in dataframes.items():
    load_to_bq(df, table_name)

print("All dataframes loaded to BigQuery successfully.")
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 942.33it/s]
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00, 999.83it/s]
# All dataframes loaded to BigQuery successfully.
