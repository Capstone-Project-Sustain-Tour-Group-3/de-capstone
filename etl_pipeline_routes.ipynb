# %% [markdown]
# ### 1. Install Library

# %%
# %pip install pandas-gbq google-cloud-bigquery
# %pip install pandas-gbq google-auth google-auth-oauthlib

# %% [markdown]
# ### 2. Import Library

# %%
import pandas as pd
import mysql.connector
from google.oauth2 import service_account
from google.cloud import bigquery
import pandas_gbq
from pandas_gbq import to_gbq
import os
from dotenv import load_dotenv
from datetime import datetime, timedelta

# %% [markdown]
# ### 3. Database Configuration

# %%
# Load konfigurasi dari .env
load_dotenv()

# MySQL configurations
rds_host = os.getenv('RDS_HOST')
rds_dbname = os.getenv('RDS_DBNAME')
rds_user = os.getenv('RDS_USER')
rds_password = os.getenv('RDS_PASSWORD')

# Google Cloud configurations
project_id = os.getenv('GOOGLE_CLOUD_PROJECT_ID')
dataset_id = os.getenv('GOOGLE_CLOUD_DATASET_ID')
google_application_credentials = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = google_application_credentials

# Koneksi ke MySQL di Amazon RDS
conn_rds = mysql.connector.connect(
    host=rds_host,
    database=rds_dbname,
    user=rds_user,
    password=rds_password
)

# %% [markdown]
# ### 4. Extract

# %% [markdown]
# #### table_to_df function below is used to extract data from a table and convert it into a dataframe

# %%
def table_to_df(table_name):
   query = f"SELECT * FROM {table_name}"
   df = pd.read_sql_query(query, conn_rds)
   return df

# %% [markdown]
# #### 4.1 Converting data from tables to dataframes

# %%
destinations_df = table_to_df('destinations')
routes_df = table_to_df('routes')
route_details_df = table_to_df('route_details')
users_df = table_to_df('users')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18200\1223067120.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn_rds)

# %% [markdown]
# #### 4.2 destinations dataframe

# %%
destinations_df
# Out:
#                                        id  \
# 0    00319825-e81b-4a93-bf9a-eef836ccf6ce
# 1    005e32da-f5fb-405c-9772-f6424c011fac
# 2    01b8da3a-3987-4976-9ae7-46d6b8eacee5
# 3    01ccaac9-97fe-42e1-8034-bc0c02471692
# 4    02834099-7ce7-44b9-8b27-e4db38f062bd
# ..                                    ...
# 365  fc6ab48d-e78f-45dd-8dec-cf67481ad9e9
# 366  fc780065-0848-467b-9625-9c24ecd2e9c2
# 367  fde8748a-2ec0-4211-89e5-12f3d63db81b
# 368  fe1ebfe5-365f-4893-aa36-91e380bb2011
# 369  ff779270-ee68-46cc-929c-cdd67d328772
#
#                               category_id                         name  \
# 0    eb77b590-b255-4ea1-b11a-d445a259ac62  Keraton Kasunanan Surakarta
# 1    eb77b590-b255-4ea1-b11a-d445a259ac62         Desa Wisata Kasongan
# 2    eb77b590-b255-4ea1-b11a-d445a259ac62          Saung Angklung Udjo
# 3    eb77b590-b255-4ea1-b11a-d445a259ac62    Museum Etnografi Sendawar
# 4    eb77b590-b255-4ea1-b11a-d445a259ac61                Danau Limboto
# ..                                    ...                          ...
# 365  eb77b590-b255-4ea1-b11a-d445a259ac61     Taman Margasatwa Ragunan
# 366  eb77b590-b255-4ea1-b11a-d445a259ac61                  Pantai Maaf
# 367  eb77b590-b255-4ea1-b11a-d445a259ac61          Piaynemo Raja Ampat
# 368  eb77b590-b255-4ea1-b11a-d445a259ac61           Wisata Pantai Gedo
# 369  eb77b590-b255-4ea1-b11a-d445a259ac61                 Danau Emfote
#
#                                            description open_time close_time  \
# 0    Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 1    Desa yang terkenal dengan kerajinan gerabah da...      8:00      17:00
# 2    Saung Angklung Udjo adalah pusat Seni dan Buda...      8:00      17:00
# 3    Museum Etnografi Sendawar merupakan museum per...      9:00      18:00
# 4    Danau ini terletak di Kecamatan Limboto, tepat...      0:00      23:59
# ..                                                 ...       ...        ...
# 365  Taman Margasatwa Ragunan jadi pilihan favorit ...      7:00      16:00
# 366  Pantai Maaf menawarkan perairan yang damai den...      6:00      18:00
# 367  Piaynemo adalah salah satu ikon wisata di Raja...     10:00      17:00
# 368  Wisata Pantai Gedo adalah destinasi pantai ind...      6:00      18:00
# 369  Danau Emfote adalah salah satu destinasi alam ...      0:00      23:59
#
#      entry_price   longitude  latitude  visit_count          created_at  \
# 0        20000.0  110.827903 -7.577736          293 2024-06-11 08:28:33
# 1            0.0  110.337978 -7.845291          243 2024-06-11 08:28:27
# 2       120000.0  107.654684 -6.897701          203 2024-06-11 08:28:33
# 3         5000.0  115.701909 -0.232651          134 2024-06-11 08:28:20
# 4            0.0  123.007543  0.577025          219 2024-06-11 08:28:21
# ..           ...         ...       ...          ...                 ...
# 365       4000.0  106.822578 -6.304916          191 2024-06-24 06:38:36
# 366      10000.0  135.496749 -3.360245          163 2024-06-11 08:28:32
# 367     150000.0  130.270813 -0.564206          123 2024-06-11 08:28:32
# 368      15000.0  135.546550 -3.309413          300 2024-06-11 08:28:32
# 369      20000.0  140.539693 -2.660878          208 2024-06-11 08:28:30
#
#              updated_at              deleted_at
# 0   2024-06-20 09:53:01 2024-06-20 09:53:01.786
# 1   2024-06-20 09:55:01 2024-06-20 09:55:01.453
# 2   2024-06-20 09:55:14 2024-06-20 09:55:14.647
# 3   2024-06-20 10:00:54 2024-06-20 10:00:54.207
# 4   2024-06-20 10:02:09 2024-06-20 10:02:09.429
# ..                  ...                     ...
# 365 2024-06-24 06:38:36                     NaT
# 366 2024-06-11 08:28:32                     NaT
# 367 2024-06-11 08:28:32                     NaT
# 368 2024-06-23 06:37:28                     NaT
# 369 2024-06-23 11:05:19                     NaT
#
# [370 rows x 13 columns]

# %% [markdown]
# #### 4.3 routes dataframe

# %%
routes_df
# Out:
#                                       id  \
# 0   02f6854d-1b57-4079-a2e3-394e9f037bb4
# 1   0458f0ec-4bbe-4950-99ad-afd5f48762d3
# 2   0c9959ab-dd26-4f23-94d1-16d739bc9b94
# 3   0fa0de42-f7e5-4a8b-b6ee-476a244c8958
# 4   116dd3f5-1287-4b5f-a3d8-856e903529d4
# 5   180e1894-3b5b-40a5-a958-cefb9ca33664
# 6   1cef156e-2c92-462e-9597-ada9dc3e3109
# 7   2644a29e-81a1-4ac1-95c8-711b19c8a09b
# 8   2eef2911-7f83-4a0a-90fa-8dbdb36987b2
# 9   2f6ee063-6fc9-44a2-962e-bb94ece1627e
# 10  30dca53e-f902-49ca-812a-38a586b386d3
# 11  3b36d28b-9424-4c45-92ca-858d7ab7618f
# 12  3bd05d68-6769-4d17-8478-e00107548447
# 18  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    3204
# 19  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    3402
# 20  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    9103
# 21  94137aaf-70a2-4246-b227-fc3507d1f98b    3471
# 22  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    1104
# 23  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    1104
# 24  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    1106
# 25  ac91e0a6-0c10-4d88-b253-294b6eb661cf    3204
# 26  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    9103
# 27  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    9103
# 28  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    9103
# 29  b3a8deaa-7466-44d6-9911-fd9cdb6ec61f    1104
# 30  fa250bda-33ab-4d58-9506-501cee510639    1104
# 31  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    8171
# 32  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    3510
# 33  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    1106
# 34  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    3217
# 35  34e333f7-1465-4dc5-a159-3035da9ee459    3204
# 36  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    9103
# 37  62e347b9-2f78-4d2f-bf48-789e5a82591d    3204
# 38  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    3217
# 39  00bddbb8-8e7d-46ab-acfc-aab981c1ada1    1903
# 40  50112dae-0b7c-47ae-93da-5bb27886b9c9    3204
# 41  ac91e0a6-0c10-4d88-b253-294b6eb661cf    3204
# 42  94137aaf-70a2-4246-b227-fc3507d1f98b    3204
#
#                                 name  \
# 0                 Liburan ke Bandung
# 1                      bandung day 1
# 2                Berwisata Ke Bantul
# 3                              Jalan
# 4                                  P
# 5                    jelajah ternate
# 6                               rute
# 7                     Pronojiwo Tour
# 8                Liburan Akhir Pekan
# 9   Jalan Jalan Keluarga akhir bulan
# 10                   Mendaki Rinjani
# 11              Liburan ke Tangerang
# 12                              Ijen
# 13                             grats
# 14                     ke curug lawe
# 15                    Jalan jalan ea
# 16                             Jalan
# 17                              uhuy
# 18                  Jalan Ke Bandung
# 19                   Jalan Ke Bantul
# 20                             Jalan
# 21                              uhuy
# 22                         Aceh cuyy
# 23                             jalan
# 24                            mantap
# 25            Liburan Akhir Semester
# 26                             Jalan
# 27                             Jalan
# 28  Perjalanan Menyenangkan Di Papua
# 29            Liburan Ke Aceh Tengah
# 30                             ruutt
# 31                  Liburan Ke Ambon
# 32    Liburan Akhir Pekan Akhir Juni
# 33                            mantap
# 34                       Jalan Sehat
# 35                Liburan Ke Bandung
# 36                             Jalan
# 37                 1 hari di Bandung
# 38      Liburan Akhur Semester Genap
# 39        Liburan Ke Aceh Bulan Juni
# 40                Liburan ke Bandung
# 41                Liburan ke Bandung
# 42                liburan bulan juni
#
#                                        start_location  start_longitude  \
# 0                                         Gedung Sate       107.620761
# 1   1600 Amphitheatre Pkwy Building 43,  Mountain ...      -122.084000
# 4    08b0725a-c0c1-4f6d-a7cb-60e136d88c72               zain@gmail.com
# ..                                    ...                          ...
# 101  fa95b90d-41a8-44fe-aea8-e3b1553532c8      puterisalsaa8@gmail.com
# 102  fc21e23a-ca8c-4cf9-8c5d-f1a56b431022             xhyeni@gmail.com
# 103  fc9e86d9-e3ba-42eb-a46c-16ba07dfeb74        tajoli5069@javnoi.com
# 104  fd13566c-bd12-4088-8537-2a52dbdca23b        Nausicaa5@example.com
# 105  fd84765b-865a-4c9b-9cc5-93ca3836e6de     zerenitymods01@gmail.com
#
#                                               password      username  \
# 0    $2a$10$waUWV4/teNb.qGj8a/1PLeQ/7XxCFvUo6A8K0jU...  yazid.syafiq
# 1    $2a$10$4w825sLhnK7X3NuN4SOntemsOtaXvbGEZAvNV1f...        paimon
# 2    $2a$10$tG82uWRFwAdiXW1xOHsmD.Xc/MxYPUmGcW3Zd6s...          ulfi
# 3    $2a$10$EH.mW4sj0PAF8kwc92Ft7eCyYWVNxmiDfSPQ2xe...    aventurine
# 4    $2a$10$B16UCmm8KU0hUralVTPaV.4nvjahndVr9I88T6b...          zain
# ..                                                 ...           ...
# 101  $2a$10$fkklkqERHa.hDRZxlPHhp.dzWPhwSchFLKzC4y0...      inisalsa
# 102  $2a$10$QpNu5wnAwZQKjvZc3QijZ.mjhw7XSx5FSC.UmjE...        xhyeni
# 103  $2a$10$D5rUZTz5z2SkdRJMeogJLODp2Xp9kHSLTVtNTrC...  testverfiy25
# 104  $2a$10$mR0l7hjnGtU6PF9V1LHTFerCZXqK.w7vBy.M.h0...     Nausicaa5
# 105  $2a$10$/lQPZ5g99QUv/TiK20NenOQFCBKEFaiVFMqX5eN...        rayhan
#
#              fullname                bio   phone_number  \
# 0       Yazid Syafiq   Manusia Biasa Aja   081393984849
# 1    Kaedehara Kazuha                      081234567890
# 2           ulfi izza                      089123456123
# 3          aventurine                      081818181818
# 4              zain m                      089231485105
# ..                ...                ...            ...
# 101   Salsa Maulidina                       08115122238
# 102     xhyeni ananda                      086182836712
# 103       Test Verify                       08123456789
# 104          John Doe                      081234567891
# 105          rayhanqr                     0895320511122
#
#                                      profile_image_url  gender  \
# 0    https://res.cloudinary.com/alta-minpro/image/u...    Pria
# 1                                              img.jpg  Wanita
# 2    https://res.cloudinary.com/alta-minpro/image/u...  Wanita
# 3    https://res.cloudinary.com/alta-minpro/image/u...    Pria
# 4    https://res.cloudinary.com/alta-minpro/image/u...    Pria
# ..                                                 ...     ...
# 101                                               None
# 102  https://res.cloudinary.com/alta-minpro/image/u...  Wanita
# 103
# 104                                               None
# 105                                               None
#
#                 city       email_verified_at              created_at  \
# 0          Pringsewu 2024-06-24 04:42:46.262 2024-05-18 03:32:14.211
# 1             Jaksel                     NaT 2024-06-16 06:33:53.904
# 2             malang                     NaT 2024-02-16 14:12:42.942
# 3    jakarta selatan                     NaT 2024-01-09 15:51:32.982
# 4             Malang                     NaT 2024-01-15 17:26:27.698
# ..               ...                     ...                     ...
# 101                  2024-06-10 12:12:21.233 2024-02-06 22:12:37.382
# 102           Malang                     NaT 2024-01-28 06:02:07.294
# 103                  2024-05-28 07:16:51.573 2024-01-26 19:32:43.861
# 104                                      NaT 2024-02-17 15:37:16.964
# 105                  2024-06-16 09:23:46.538 2024-06-10 03:28:12.777
#
#                  updated_at deleted_at    province  \
# 0   2024-06-24 14:36:54.713       None     Lampung
# 1   2024-06-24 03:16:38.804       None
# 2   2024-06-24 03:22:39.515       None  jawa timur
# 3   2024-06-23 11:20:54.103       None     jakarta
# 4   2024-06-16 13:34:19.510       None  Jawa Timur
# ..                      ...        ...         ...
# 101 2024-06-10 12:12:23.104       None
# 102 2024-06-19 06:14:44.495       None  Jawa Timur
# 103 2024-05-28 07:16:51.576       None
# 104 2024-06-12 07:00:16.507       None
# 105 2024-06-16 09:23:49.107       None
#
#                                          refresh_token
# 0    eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJZCI6I...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 101  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJZCI6I...
# 102
# 103                                               None
# 104
# 105  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJJZCI6I...
#
# [106 rows x 16 columns]

# %% [markdown]
# #### 4.6 Closing connection

# %%
conn_rds.close()

# %% [markdown]
# ### 5. Transformation

# %% [markdown]
# #### 5.1 Selecting subsets of each dataframe

# %%
# Kamus pemetaan bulan dalam bahasa Indonesia
month_mapping = {
    1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',
    5: 'Mei', 6: 'Jun', 7: 'Jul', 8: 'Agu',
    9: 'Sep', 10: 'Okt', 11: 'Nov', 12: 'Des'
}

# Ekstraksi tahun, bulan, dan hari
users_df['tahun'] = users_df['created_at'].dt.year
users_df['bulan'] = users_df['created_at'].dt.month.map(month_mapping)
users_df['tanggal'] = users_df['created_at'].dt.day
users_df['tanggallengkap'] = pd.to_datetime(users_df['created_at'].dt.date)

dim_destinations = destinations_df[['id', 'name', 'description', 'open_time', 'close_time', 'entry_price', 'longitude', 'latitude', 'visit_count']]
dim_routes = routes_df[['id', 'name', 'start_longitude', 'start_latitude', 'price']]
dim_route_details = route_details_df[['id', 'longitude', 'latitude', 'duration', 'order', 'visit_start', 'visit_end']]
dim_users = users_df[['id', 'email', 'username', 'fullname', 'phone_number', 'gender', 'city', 'province', 'tahun', 'bulan', 'tanggal', 'tanggallengkap']]

# %% [markdown]
# #### 5.2 destinations dimension

# %%
dim_destinations
# Out:
#                                        id                         name  \
# 0    00319825-e81b-4a93-bf9a-eef836ccf6ce  Keraton Kasunanan Surakarta
# 1    005e32da-f5fb-405c-9772-f6424c011fac         Desa Wisata Kasongan
# 2    01b8da3a-3987-4976-9ae7-46d6b8eacee5          Saung Angklung Udjo
# 3    01ccaac9-97fe-42e1-8034-bc0c02471692    Museum Etnografi Sendawar
# 4    02834099-7ce7-44b9-8b27-e4db38f062bd                Danau Limboto
# ..                                    ...                          ...
# 365  fc6ab48d-e78f-45dd-8dec-cf67481ad9e9     Taman Margasatwa Ragunan
# 366  fc780065-0848-467b-9625-9c24ecd2e9c2                  Pantai Maaf
# 367  fde8748a-2ec0-4211-89e5-12f3d63db81b          Piaynemo Raja Ampat
# 368  fe1ebfe5-365f-4893-aa36-91e380bb2011           Wisata Pantai Gedo
# 369  ff779270-ee68-46cc-929c-cdd67d328772                 Danau Emfote
#
#                                            description open_time close_time  \
# 0    Keraton Kasunanan Surakarta adalah istana resm...      9:00      14:00
# 1    Desa yang terkenal dengan kerajinan gerabah da...      8:00      17:00
# 2    Saung Angklung Udjo adalah pusat Seni dan Buda...      8:00      17:00
# 3    Museum Etnografi Sendawar merupakan museum per...      9:00      18:00
# 4    Danau ini terletak di Kecamatan Limboto, tepat...      0:00      23:59
# ..                                                 ...       ...        ...
# 365  Taman Margasatwa Ragunan jadi pilihan favorit ...      7:00      16:00
# 366  Pantai Maaf menawarkan perairan yang damai den...      6:00      18:00
# 367  Piaynemo adalah salah satu ikon wisata di Raja...     10:00      17:00
# 368  Wisata Pantai Gedo adalah destinasi pantai ind...      6:00      18:00
# 369  Danau Emfote adalah salah satu destinasi alam ...      0:00      23:59
#
#      entry_price   longitude  latitude  visit_count
# 0        20000.0  110.827903 -7.577736          293
# 1            0.0  110.337978 -7.845291          243
# 2       120000.0  107.654684 -6.897701          203
# 3         5000.0  115.701909 -0.232651          134
# 4            0.0  123.007543  0.577025          219
# ..           ...         ...       ...          ...
# 365       4000.0  106.822578 -6.304916          191
# 366      10000.0  135.496749 -3.360245          163
# 367     150000.0  130.270813 -0.564206          123
# 368      15000.0  135.546550 -3.309413          300
# 369      20000.0  140.539693 -2.660878          208
#
# [370 rows x 9 columns]

# %% [markdown]
# #### 5.3 routes dimension

# %%
dim_routes
# Out:
#                                       id                              name  \
# 0   02f6854d-1b57-4079-a2e3-394e9f037bb4                Liburan ke Bandung
# 1   0458f0ec-4bbe-4950-99ad-afd5f48762d3                     bandung day 1
# 2   0c9959ab-dd26-4f23-94d1-16d739bc9b94               Berwisata Ke Bantul
# 3   0fa0de42-f7e5-4a8b-b6ee-476a244c8958                             Jalan
# 4   116dd3f5-1287-4b5f-a3d8-856e903529d4                                 P
# 5   180e1894-3b5b-40a5-a958-cefb9ca33664                   jelajah ternate
# 6   1cef156e-2c92-462e-9597-ada9dc3e3109                              rute
# 7   2644a29e-81a1-4ac1-95c8-711b19c8a09b                    Pronojiwo Tour
# 8   2eef2911-7f83-4a0a-90fa-8dbdb36987b2               Liburan Akhir Pekan
# 9   2f6ee063-6fc9-44a2-962e-bb94ece1627e  Jalan Jalan Keluarga akhir bulan
# 10  30dca53e-f902-49ca-812a-38a586b386d3                   Mendaki Rinjani
# 11  3b36d28b-9424-4c45-92ca-858d7ab7618f              Liburan ke Tangerang
# 12  3bd05d68-6769-4d17-8478-e00107548447                              Ijen
# 13  404ac9aa-af41-4041-9977-e0f1e5e0bcfd                             grats
# 14  45478b42-f990-4f6f-ab93-8007f2478779                     ke curug lawe
# 15  535d4453-8727-4583-8334-aeab30ff8653                    Jalan jalan ea
# 16  5ac229cc-ee5c-4b2e-be76-f958bcc21e77                             Jalan
# 17  640a3c9c-b709-4297-924b-745418e6e903                              uhuy
# 18  696a55f3-fb72-4c25-9121-b6b0fedeb98e                  Jalan Ke Bandung
# 19  7aca3d8a-70e6-447e-85c2-291b852a1ae6                   Jalan Ke Bantul
# 20  7c8ada92-890c-4558-ac7a-f89053d9ee2c                             Jalan
# 21  7c9badfb-b98a-4512-99ac-901ea23bf9de                              uhuy
# 22  811894eb-6e05-45f4-b2ba-a3c80dc55ab8                         Aceh cuyy
# 23  8a10debc-3a23-45e1-b60e-a64025344a21                             jalan
# 24  9328d7c5-5548-4444-92c2-87882688a46a                            mantap
# 25  9a913aba-1385-49ba-8442-b422815da1ed            Liburan Akhir Semester
# 26  9bb8781c-54a4-4acd-99f9-eb9d4c657c7f                             Jalan
# 27  a667b392-099b-4bb8-9264-5c0f983c3777                             Jalan
# 28  ac367500-7ade-484e-8c2d-0d4b4ddcee9d  Perjalanan Menyenangkan Di Papua
# 29  b458673d-5f9f-43d1-aef0-d3be7c1c6c87            Liburan Ke Aceh Tengah
# 30  b84b2846-96b0-48e3-8c34-809b3b3a5e3c                             ruutt
# 31  b8c3de48-ae18-4fcb-bffc-688b4ecbe8f0                  Liburan Ke Ambon
# 32  c5b34b31-d777-4d76-a7c6-d57b2fe0f33d    Liburan Akhir Pekan Akhir Juni
# 33  c657b3f5-4973-4861-b2ce-d86f19227390                            mantap
# 34  ce271f06-dbb1-4155-b2a9-40ad9d40be1c                       Jalan Sehat
# 35  ce2db343-fd75-4334-b6ad-658073ed2cf5                Liburan Ke Bandung
# 36  ce97e7c3-21b9-4d84-9534-9142cf9abd30                             Jalan
# 37  cf0c6d65-9ab3-44b9-bd1a-cf44304f5827                 1 hari di Bandung
# 38  e62a259d-f8f4-49ef-8272-264cfb20b172      Liburan Akhur Semester Genap
# 39  e99e9744-ad97-42c6-a7d0-b93d4e60edf6        Liburan Ke Aceh Bulan Juni
# 40  eef97de7-8bed-422c-a788-127ae77bb21f                Liburan ke Bandung
# 41  f34b3c72-3829-4ee1-993a-63cf37637b11                Liburan ke Bandung
# 42  f6a0ec4c-7056-4109-9577-52be8072f5db                liburan bulan juni
#
#     start_longitude  start_latitude      price
# 0        107.620761       -6.916096   200000.0
# 1       -122.084000       37.421998   200000.0
# 2        104.991381       -5.410041   170000.0
# 3        104.991384       -5.410041   100000.0
# 4        104.985617       -5.333118    60000.0
# 5        116.111153       -8.594150    65000.0
# 6        112.648574       -7.928092    90000.0
# 7        112.758205       -7.228514    45000.0
# 8        104.991384       -5.410042    60000.0
# 9         98.512382        3.644328   500000.0
# 10       104.985617       -5.333118  2600000.0
# 11       107.620761       -6.916096    45000.0
# 12       104.991382       -5.410042  5002000.0
# 13       112.734704       -7.308487   150000.0
# 14       111.140302       -6.713127    80000.0
# 15       114.586753       -3.296277   165000.0
# 16       104.991384       -5.410041   100000.0
# 17       112.734704       -7.308487    50000.0
# 18       104.985617       -5.333118   100000.0
# 19       104.985617       -5.333118    90000.0
# 20       104.991384       -5.410041   100000.0
# 21       112.728241       -7.384667    90000.0
# 22       104.985617       -5.333118     5000.0
# 23       104.991384       -5.410042   150000.0
# 24       104.991388       -5.410042   100000.0
# 25        98.512424        3.644439   150000.0
# 26       104.991384       -5.410041   100000.0
# 27       104.991384       -5.410041   100000.0
# 28       104.991381       -5.410041   120000.0
# 29       104.991377       -5.410039    70000.0
# 30       112.648504       -7.928099   500000.0
# 31       104.991386       -5.410040    10000.0
# 32       104.985617       -5.333118   500000.0
# 33       104.991388       -5.410042   100000.0
# 34       104.985617       -5.333118   100000.0
# 35       104.985617       -5.333118    90000.0
# 36       104.991384       -5.410041   100000.0
# 37       106.803327       -6.399321   200000.0
# 38       104.985617       -5.333118    80000.0
# 39       104.985617       -5.333118    50000.0
# 40       116.832209       -1.276377   137000.0
# 41       107.620761       -6.916096   200000.0
# 42       112.728241       -7.384667   152000.0

# %% [markdown]
# #### 5.4 route_details dimension

# %%
dim_route_details['visit_start'] = dim_route_details['visit_start'].astype(str)
dim_route_details['visit_end'] = dim_route_details['visit_end'].astype(str)
dim_route_details
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18200\476546220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dim_route_details['visit_start'] = dim_route_details['visit_start'].astype(str)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_18200\476546220.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dim_route_details['visit_end'] = dim_route_details['visit_end'].astype(str)
#                                       id   longitude  latitude  duration  \
# 0   04fe05f6-7498-40fb-a1e6-8ef51be2a10c  127.307562  0.836181      6300
# 1   0771cb1e-238d-4bf3-be0c-1fa3ffb0d143  140.518725 -2.613298      8640
# 2   07b19224-517f-4071-be96-c4136f92ccee  140.451761 -2.579639     10800
# 3   083731a3-5252-4835-9680-e184b3758c8b  107.621455 -6.900718      5400
# 4   0dfb44fa-c5b5-4af1-8f7e-f10d09198f82   96.996653  4.592379     33185
# ..                                   ...         ...       ...       ...
# 85  f30e8f0d-6019-4dc2-ad7d-a6fa88c50785  107.402431 -7.166188      1800
# 86  f4449f3e-995d-458b-9ed1-a94e338cc1ac  103.159275 -4.022511      2700
# 87  f5009d18-3e42-4832-9f62-be7d5fdb25e8  116.461640 -8.410276      5400
# 88  f9640b63-fa9e-459d-8d72-032b05ff7a3b  107.676829 -6.842148      6600
# 89  ffa44445-cf56-44ae-a25b-c6ebbc60fabf  107.654684 -6.897701      5400
#
#     order      visit_start        visit_end
# 0       3  0 days 13:00:00  0 days 14:00:00
# 1       3  0 days 16:45:00  0 days 17:45:00
# 2       1  0 days 10:00:00  0 days 12:00:00
# 3       2  0 days 11:55:00  0 days 12:55:00
# 4       1  0 days 10:15:00  0 days 17:15:00
# ..    ...              ...              ...
# 85      1  0 days 09:00:00  0 days 10:30:00
# 86      2  0 days 11:00:00  0 days 11:45:00
# 87      1  0 days 07:00:00  0 days 14:00:00
# 88      3  0 days 14:30:00  0 days 15:45:00
# 89      3  0 days 15:00:00  0 days 16:30:00
#
# [90 rows x 7 columns]

# %% [markdown]
# #### 5.5 users dimension

# %%
dim_users
# Out:
#                                        id                        email  \
# 0    00bddbb8-8e7d-46ab-acfc-aab981c1ada1  irsyadyazidsyafiq@gmail.com
# 1    03d7240b-3e9b-4105-ac93-a926b752bb81             shuu@example.com
# 2    05d6e970-851b-4a8d-8869-587ebe5273cd           ulfiizza@gmail.com
# 3    083cb941-9a91-4ea4-af6e-5b25384ff00b            aventur@gmail.com
# 4    08b0725a-c0c1-4f6d-a7cb-60e136d88c72               zain@gmail.com
# ..                                    ...                          ...
# 101  fa95b90d-41a8-44fe-aea8-e3b1553532c8      puterisalsaa8@gmail.com
# 102  fc21e23a-ca8c-4cf9-8c5d-f1a56b431022             xhyeni@gmail.com
# 103  fc9e86d9-e3ba-42eb-a46c-16ba07dfeb74        tajoli5069@javnoi.com
# 104  fd13566c-bd12-4088-8537-2a52dbdca23b        Nausicaa5@example.com
# 105  fd84765b-865a-4c9b-9cc5-93ca3836e6de     zerenitymods01@gmail.com
#
#          username          fullname   phone_number  gender             city  \
# 0    yazid.syafiq     Yazid Syafiq    081393984849    Pria        Pringsewu
# 1          paimon  Kaedehara Kazuha   081234567890  Wanita           Jaksel
# 2            ulfi         ulfi izza   089123456123  Wanita           malang
# 3      aventurine        aventurine   081818181818    Pria  jakarta selatan
# 4            zain            zain m   089231485105    Pria           Malang
# ..            ...               ...            ...     ...              ...
# 101      inisalsa   Salsa Maulidina    08115122238
# 102        xhyeni     xhyeni ananda   086182836712  Wanita           Malang
# 103  testverfiy25       Test Verify    08123456789
# 104     Nausicaa5          John Doe   081234567891
# 105        rayhan          rayhanqr  0895320511122
#
#        province  tahun bulan  tanggal tanggallengkap
# 0       Lampung   2024   Mei       18     2024-05-18
# 1                 2024   Jun       16     2024-06-16
# 2    jawa timur   2024   Feb       16     2024-02-16
# 3       jakarta   2024   Jan        9     2024-01-09
# 4    Jawa Timur   2024   Jan       15     2024-01-15
# ..          ...    ...   ...      ...            ...
# 101               2024   Feb        6     2024-02-06
# 102  Jawa Timur   2024   Jan       28     2024-01-28
# 103               2024   Jan       26     2024-01-26
# 104               2024   Feb       17     2024-02-17
# 105               2024   Jun       10     2024-06-10
#
# [106 rows x 12 columns]

# %% [markdown]
# #### 5.6 routes_fact

# %%
# merging dataframes
merged_df = pd.merge(routes_df, route_details_df, left_on='id', right_on='route_id', suffixes=('_routes', '_route_details'))
merged_df = pd.merge(merged_df, users_df, left_on='user_id', right_on='id', suffixes=('_routes', '_users'))
merged_df = pd.merge(merged_df, destinations_df, left_on='destination_id', right_on='id', suffixes=('_routes_users', '_destinations'))

# Pilih subset kolom
routes_fact = merged_df[['id_routes', 'user_id', 'id_route_details', 'id_destinations']]

# renaming some of columns name
routes_fact = routes_fact.rename(columns={"id_routes": "route_id", 
                                          "id_route_details": "route_details_id", 
                                          "id_destinations": "destinations_id"})

# adding user_count and route_count columns
routes_fact['user_count'] = 1
routes_fact['route_count'] = 1

# Menghitung total destinations untuk setiap route_id
routes_fact['total_destination'] = routes_fact.groupby('route_id')['destinations_id'].transform('count')

# display the dataframe
routes_fact
# Out:
#                                 route_id  \
# 0   02f6854d-1b57-4079-a2e3-394e9f037bb4
# 1   f34b3c72-3829-4ee1-993a-63cf37637b11
# 2   02f6854d-1b57-4079-a2e3-394e9f037bb4
# 3   f34b3c72-3829-4ee1-993a-63cf37637b11
# 4   0458f0ec-4bbe-4950-99ad-afd5f48762d3
# ..                                   ...
# 85  7c9badfb-b98a-4512-99ac-901ea23bf9de
# 86  7c9badfb-b98a-4512-99ac-901ea23bf9de
# 87  45478b42-f990-4f6f-ab93-8007f2478779
# 88  ce2db343-fd75-4334-b6ad-658073ed2cf5
# 89  cf0c6d65-9ab3-44b9-bd1a-cf44304f5827
#
#                                  user_id  \
# 0   ac91e0a6-0c10-4d88-b253-294b6eb661cf
# 1   ac91e0a6-0c10-4d88-b253-294b6eb661cf
# 2   ac91e0a6-0c10-4d88-b253-294b6eb661cf
# 3   ac91e0a6-0c10-4d88-b253-294b6eb661cf
# 4   a48e02bb-6a68-4586-85e4-b038d795da5b
# ..                                   ...
# 85  94137aaf-70a2-4246-b227-fc3507d1f98b
# 86  94137aaf-70a2-4246-b227-fc3507d1f98b
# 87  ed295b2a-0a9f-40a0-8cae-461531ad949e
# 88  34e333f7-1465-4dc5-a159-3035da9ee459
# 89  62e347b9-2f78-4d2f-bf48-789e5a82591d
#
#                         route_details_id  \
# 0   457c1a86-15aa-47da-9b57-dcd4814074a9
# 1   c8096bca-7ffd-4f3f-9e8a-97aa735f5efd
# 2   55fab257-2df8-4ec7-87b7-1f883d8819f4
# 3   453e97ca-fc14-4fef-81e4-4482738530d0
# 4   f30e8f0d-6019-4dc2-ad7d-a6fa88c50785
# ..                                   ...
# 85  4355697e-20cd-453b-8823-2069b328cc48
# 86  b0adb48f-f922-4830-9794-218d92b6a505
# 87  e96b4de5-eaf7-4ed0-90af-f41b051795cd
# 88  d4959467-c893-44cf-8d0e-0978fcb1dce6
# 89  27580f8e-a0bc-4cf8-b491-1bae1ea69579
#
#                          destinations_id  user_count  route_count  \
# 0   01b8da3a-3987-4976-9ae7-46d6b8eacee5           1            1
# 1   01b8da3a-3987-4976-9ae7-46d6b8eacee5           1            1
# 2   5fb0bedc-f1fa-4197-814f-f97155092473           1            1
# 3   5fb0bedc-f1fa-4197-814f-f97155092473           1            1
# 4   5fb0bedc-f1fa-4197-814f-f97155092473           1            1
# ..                                   ...         ...          ...
# 85  4388e724-d0b8-46e0-80bd-1362210b1cc1           1            1
# 86  c752381e-bf5e-48c7-b8f2-27a07959bee8           1            1
# 87  cafb4a28-6c52-4157-baaf-7080e3b642c6           1            1
# 88  73697664-ba03-4de1-ad47-13fa4f95abcd           1            1
# 89  73697664-ba03-4de1-ad47-13fa4f95abcd           1            1
#
#     total_destination
# 0                   3
# 1                   3
# 2                   3
# 3                   3
# 4                   3
# ..                ...
# 85                  2
# 86                  2
# 87                  1
# 88                  3
# 89                  3
#
# [90 rows x 7 columns]

# %% [markdown]
# ### 6. Load

# %% [markdown]
# #### load _to_gbq function below is used to load extract data from a dataframe into a table in google big query

# %%
def load_to_gbq(credentials, project_id, dataset_id, table_names, dataframes):
   for df, table_name in zip(dataframes, table_names):
      table_full_id = f'{project_id}.{dataset_id}.{table_name}'
      to_gbq(df, table_full_id, project_id=project_id, if_exists='replace', credentials=credentials)
      print(f'Table {table_name} loaded successfully!')

# %% [markdown]
# #### 6.1 Load to Big Query

# %%
credentials = service_account.Credentials.from_service_account_file(google_application_credentials)

dfs = [dim_destinations, dim_routes, dim_route_details, dim_users, routes_fact]
tables = ['dim_destinations', 'dim_routes', 'dim_route_details', 'dim_users', 'routes_fact']

load_to_gbq(credentials, project_id, dataset_id, tables, dfs)
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_destinations loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_routes loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_route_details loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table dim_users loaded successfully!
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Table routes_fact loaded successfully!
